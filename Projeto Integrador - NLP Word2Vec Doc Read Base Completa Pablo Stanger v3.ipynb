# %%
import pandas as pd 
import csv
import spacy
import pt_core_news_sm
import string
import re
import docx2txt

from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
from nltk import ngrams
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from geopy import geocoders  
from time import time  
from collections import defaultdict
from gensim.models.phrases import Phrases, Phraser

import logging
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
my_text = docx2txt.process("Pablo Stanger CV português v4.docx")
print(my_text)
# Out:
# Pablo Stanger
#
# Fone: (55-11) 97109-2031
#
# e-mail: pablostanger@gmail.com
#
# LinkedIn: https://www.linkedin.com/in/pablo-stanger
#
# Singularity: https://singularityuglobal.org/profile/pablo-stanger
#
#
#
# Resumo
#
# Auto motivado, obcecado com o sucesso do cliente, empreendedor, fortes competências em vendas de campo e excelentes relações interpessoais. Executivo sênior com mais de 10 anos de experiência em Vendas Consultiva de Soluções, Desenvolvimento de Negócios e Liderança de Vendas com soluções suportadas por tecnologias disruptivas para clientes estratégicos em São Paulo, Rio de Janeiro e Brasília, segmentados nas indústrias de bancos, seguradoras, varejo, telecom e bens de consumo. Experiência no desenvolvimento e liderança de equipes de venda Hybrid Cloud de alto desempenho focadas em resultados de curto e longo prazos. Experiência no desenvolvimento e liderança de equipes de oferta de produtos Hybrid Cloud para acelerar a adoção da plataforma pelo ecossistema por meio de Integradores de Sistemas Globais (GMSI), Parceiros de Negócios e ISVs.
#
# Experiência em Liderança de Vendas: Forte atuação na construção e manutenção de relacionamentos com C-level LOBs (Negócios) e TI, influenciando o direcionamento estratégico de longo prazo, e atuando como um assessor confiável com expertise em liderança e gestão estratégica de territórios, incluindo planejamento de contas, geração de oportunidades e evolução do pipeline, relacionamento e comunicação com clientes, e estratégia de go-to-market. Experiência com propostas e negociações complexas, retorno de investimentos (ROI), estratégias de parcerias e ofertas de produtos Cloud.
#
# Colaborativo em um ambiente multifuncional e experiente na atuação com especialistas técnicos, experts da indústria, especialistas em marketing e parceiros de negócios para otimizar resultados e desenvolver oportunidades para crescimento de negócios em novos clientes e na base de clientes existente. Experiente na exploração e compreensão de requisitos de negócios complexos, apresentando soluções inovadoras em Cloud e negociando "valor único" na frente do cliente, sempre focado em ser essencial para os clientes e ajudando-os em sua jornada de transformação digital.
#
# Experiência no desenvolvimento e liderança de equipes criativas e de alto desempenho para formular, desenvolver, implementar e transformar ideias exponenciais em negócios reais. Treinado na exploração e compreensão de necessidades de negócios e prototipagem e testes por meio de MVPs para explorar “valor único” por meio do processo de feedback construir-medir-aprender.
#
# Importante conhecimento de negócios e diferentes indústrias com especialização em bancos e seguradoras. Profundo entendimento dos principais recursos e das estratégias das plataformas Cloud. Participação em todos Cloud Summits Brazil 2018: AWS, Google, Microsoft e Oracle. Atualmente inscrito no programa presencial de imersão em Ciência de Dados e Machine Learning. Aptidão técnica em plataformas Cloud e AI (IaaS, PaaS e SaaS), IoT, Analytics, DevOps, Mobile, Blockchain, Sistemas Integrados e Middleware Software (SOA/Integração, BPM/Transformação de Processos, Gerenciamento de Serviços de TI, API Management, Servidores de Aplicação e Vídeo).
#
# MBA em Negócios e especialização em liderança exponencial, novos modelos de negócios e tecnologias disruptivas. Conclusão de dois programas internacionais de imersão em Inovação Digital em 2018: Singularity University Innovation Program 2018: programa prático de imersão que prepara líderes para que possam desenvolver um plano de inovação de transformação digital para o seu negócio, explorando os mais recentes modelos de liderança, estruturas organizacionais,  novos modelos de negócio e tecnologias. Stanford University Ignite Program 2018: programa de imersão que fornece os fundamentos de negócio e a experiência prática necessária para formular, desenvolver, comercializar e transformar ideias exponenciais em empreendimentos reais. A apresentação final foi realizada para um painel de venture capitalists, investidores anjos, especialistas do setor e empresários experientes.
#
# 		Fundador da SOFIA Plataforma, uma das seis finalistas brasileiras e melhores startups em educação em 2018 (Ed Techs) no programa Singularity University Global Impact Challenge Brazil 2018:
#
# https://revistapegn.globo.com/Startups/noticia/2018/06/medroom-e-sofia-vencem-etapa-paulista-do-singularityu-brazil-global-impact-challenge-2018.html
#
# Como membro da Singularity University Chapter São Paulo, é participante ativo e entusiasta de comunidades brasileiras de StartUps com treinamentos técnicos e de negócios.
#
# Proficiência profissional em inglês, espanhol e português.
#
# Experiência Profissional
#
# Co-fundador e CEO @ SOFIA Plataforma (2018 até o momento)
#
# Com métodos e práticas integradas e tecnologias disruptivas, SOFIA Plataforma irá integrar, orientar e instrumentalizar os profissionais de escolas, terapeutas e famílias com o melhor caminho sugerido de aprendizagem e ensino para estudantes com deficiência intelectual nos âmbitos educacional, terapêutico e social.
#
# Co-fundador e CEO @ Bikepass (2018 até o momento)
#
# Suportada por tecnologias de inteligência artificial e realidade virtual, a plataforma Bikepass fornecerá bicicletas e outros veículos elétricos para usuários corporativos, reduzindo congestionamentos e emissões de CO2 e melhorando a qualidade de vida.
#
# Executivo de Estratégia e Vendas da Unidade Hybrid Cloud, IBM Brasil (2015 a 2018)
#
# Responsável por (i) liderança e execução de vendas de Hybrid Cloud (IaaS, PaaS, SaaS e on-premise) para os +50 clientes mais estratégicos em São Paulo, Rio de Janeiro e Brasília, segmentados em bancos, seguradoras, varejo, telecom e outras indústrias, (ii) desenvolvimento de relacionamentos com C-level LOBs e executivos de TI, (iii) apresentações de soluções para C-level com assessoria estratégica e aconselhamento, com suporte de experts, (iv) negociações e elaboração de propostas financeiras Hybrid Cloud para as áreas de Compras dos Clientes, e (v) efetiva gestão estratégica de território, incluindo planejamento de contas, geração de oportunidades e evolução do pipeline, relacionamento e comunicação com clientes, e desenvolvimento de parceiros. Em 2017 foi responsável pelos três maiores bancos brasileiros: Bradesco, Itaú e Santander. Reconhecido como um dos melhores desempenhos em Vendas, superando metas em 2016 e 2017 e entregando altos índices de crescimento.
#
#
# Cases de destaque:
#
# Cliente
#
# Desafios de Negócios e TI
#
# Soluções
#
# Itaú Unibanco
#
# Melhora na entrega contínua e na disponibilidade, e redução dos custos de DevOps no Itaú On-Premise Private Cloud
#
# PaaS (ICP Bluemix), Smart Process, IT Service Management, Application Server e Messaging
#
# Santander
#
# Melhora na agilidade e acuidade de processos orientados a documentos
#
# Solução para captura de Documentos e Dados com Watson Cognitive (reconhecimento visual)
#
# Bradesco e
#
# Bradesco Seguros
#
# Melhora na entrega contínua e na disponibilidade e redução dos custos de migração de aplicações legadas para Bradesco On-Premise Private Cloud
#
# PaaS (ICP Bluemix), Smart Process, IT Service Management, DevOps Virtual Testing, Application Server, Integration, Messaging e Datapowers
#
# Azul Seguros por meio de Parceiro de Negócios
#
# Melhora na entrega contínua, disponibilidade e controle dos processos corporativos
#
# Smart Process e Integration
#
# Alelo por meio de Parceiro de Negócios
#
# Melhora na entrega contínua, disponibilidade, controle dos processos corporativos e cadeia de integração de negócios por meio de APIs
#
# SaaS (Bluemix, Smart Process e Gestão de API), Datapowers
#
# Banco Original por meio de Parceiro de Negócios
#
# Melhora no time-to-market e de serviços em aplicações de Mobility para clientes
#
# Mobile First, Smart Process e Business Integration
#
# AES por meio de Parceiro de Negócios
#
# Melhora nos serviços aos clientes por meio de processos corporativos integrados
#
# Smart Process
#
# TIM por meio de Parceiro de Negócios
#
# Melhora na segurança e capacidades de integração com parceiros de negócios por meio de API
#
# Datapowers
#
# Caixa por meio de Parceiro de Negócios
#
# Melhora no time-to-market de aplicações móveis
#
# Mobile Platform
#
#
#
# Gerente de Vendas WebSphere, IBM Brasil (2012 a 2014)
#
# Responsável por (i) liderança e execução de vendas da marca WebSphere nos +80 clientes mais estratégicos em São Paulo, Rio de Janeiro e Brasília, segmentados por bancos, seguradoras, varejo, telecom e bens de consumo, (ii) apresentações de soluções para C-level com assessoria estratégica e aconselhamento, com suporte de experts, (iii) desenvolvimento de relacionamentos com C-level LOBs e executivos de TI, (iv) negociações e elaboração de propostas financeiras WebSphere para as áreas de Compras dos Clientes, (v) efetiva gestão estratégica de território, incluindo planejamento de contas, geração de oportunidades e evolução do pipeline, relacionamento e comunicação com clientes, e desenvolvimento de parceiros, e (vi) oferta da marca WebSphere e ações de marketing para promover visibilidade de seus produtos e reconhecimento da marca. Reconhecido como gerente de vendas de melhor desempenho em 2012 e 2013, entregando índices de crescimento de 2 dígitos e contribuindo com +85% da receita anual total da marca WebSphere.
#
# Gerente de Conta de Software - Banco Bradesco e Bradesco Seguros, IBM Brasil (2003 a 2011)
#
# Responsável por (i) venda de soluções apoiado por tecnologias inovadoras para C-level LOBs e executivos de TI, (ii) desenvolvimento de relacionamento com C-level LOBs e executivos de TI, (iii) apresentações mensais para CIO e Diretores dos resultados dos projetos em andamento, direções estratégicas e novas iniciativas, (iv) liderança de todas as negociações de software IBM e elaboração das propostas financeiras para as áreas de Compras, e (v) efetiva gestão estratégica de território, incluindo planejamento de contas, geração de oportunidades e evolução do pipeline, relacionamento e comunicação com clientes, e desenvolvimento de parceiros. Reconhecido como o melhor desempenho em Venda de Software por 6 anos consecutivos, incrementando a receita em 10 vezes, em 5 anos. A IBM se tornou a parceira tecnológica número 1 do Bradesco em 5 anos, e o Bradesco se tornou a maior conta da IBM América Latina em receita e lucro em 2010.
#
# Desenvolvedor de Software e Engenheiro de Sistemas, IBM Brasil (1999 a 2002)
#
# Responsável pela criação, análise e implementação de soluções de Automação Bancária. Liderança de equipe técnica, com habilidade para identificar, desenvolver e capitalizar novas soluções bancárias personalizadas.
#
# Educação
#
# Stanford University Ignite Program 2018
#
# Singularity University Innovation Program 2018
#
# Data Science and Big Data Analytics: Making Data-Driven Decisions, Massachusetts Institute of Technology, 2018
#
# Singularity University Global Summit 2017
#
# FINTECH Certificate Course: Future Commerce 2016, Massachusetts Institute of Technology, 2016
#
# Programa Executivo - Advanced Sales Leadership, Boston University, 2012
#
# Programa Executivo - Driving Strategic Value From IT, Northwestern University - Kellogg School of Management, 2010
#
# MBA (MBA Extensão da Fundação Dom Cabral), Northwestern University - Kellogg School of Management, 2009
#
# Business and Industry Insight Program, Harvard Business School, 2008
#
# Programa de Especialização em Bancos e Seguros, Fundação Getúlio Vargas, 2007
#
# MBA, Fundação Dom Cabral, 2005
#
# Administração de Negócios (CEAG), Fundação Getúlio Vargas, 1998
#
# Marketing Analysis and Planning Course, University of Pennsylvania’s Wharton School, 1991
#
# Bacharel em Matemática, FSA, 1988
#
# Informações Adicionais
#
# Apoio voluntário e financeiro a entidades filantrópicas
#
# Baterista, corrida de maratona e montanhismo como hobbies

# %%
df = pd.read_csv(r'Vagas+Catho+Gupy+Indeed+LatitudeLongitude.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          Cidade  \
# 0           0        brasilia
# 1           1        londrina
# 2           2  rio de janeiro
# 3           3  rio de janeiro
# 4           4  rio de janeiro
#
#                                         Competências Descrição_da_empresa  \
# 0  o cientista de dados ou data scientist e consi...                  NaN
# 1  utilizar modelos matematicos e estatisticos, p...                  NaN
# 2  interpretacao de tendencias. refino de base de...                  NaN
# 3  modelar problemas complexos, identificar oport...                  NaN
# 4  realizar projetos sprint de desenvolvimento e ...                  NaN
#
#   Empresa Estado                                       Nome_da_vaga  \
# 0     NaN     DF        vaga de cientista de dados em brasilia - df
# 1     NaN     PR        vaga de cientista de dados em londrina - pr
# 2     NaN     RJ  vaga de data scientist junior/ cientista de da...
# 3     NaN     RJ  vaga de data scientist senior/ cientista de da...
# 4     NaN     RJ  vaga de cientista de dados (aut) em rio de jan...
#
#      Termo_pesquisado   Latitude  Longitude
# 0  cientista de dados -15.793404 -47.882317
# 1  cientista de dados -23.311288 -51.159502
# 2  cientista de dados -22.911014 -43.209373
# 3  cientista de dados -22.911014 -43.209373
# 4  cientista de dados -22.911014 -43.209373

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278 entries, 0 to 2277
# Data columns (total 10 columns):
# Unnamed: 0              2278 non-null int64
# Cidade                  2278 non-null object
# Competências            2278 non-null object
# Descrição_da_empresa    541 non-null object
# Empresa                 830 non-null object
# Estado                  1509 non-null object
# Nome_da_vaga            2278 non-null object
# Termo_pesquisado        2278 non-null object
# Latitude                2278 non-null float64
# Longitude               2278 non-null float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 178.0+ KB

# %%
df.drop_duplicates(subset ="Competências", inplace = True)

# %%
df = df.reset_index(drop=True)

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.groupby(['Termo_pesquisado']).count()
# Out:
#                                 Cidade  Competências  Descrição_da_empresa  \
# Termo_pesquisado
# analista de dados                  383           383                   186
# analista de negocios               205           205                   145
# analista de negocios               654           654                     0
# business analytics                  17            17                     4
# business inteligence                 8             8                     3
# cientista de dados                 104           104                    12
# data analytics                      27            27                    19
# data analytics                      44            44                     0
# data science                        62            62                     8
# data scientist                       1             1                     0
# engenheiro de dados                 44            44                    27
# engenheiro de dados                 27            27                     0
# engenheiro de machine learning       8             8                     1
# inteligencia de dados                1             1                     0
# inteligencia de negocios            83            83                    27
# people analytics                     2             2                     0
#
#                                 Empresa  Estado  Nome_da_vaga  Latitude  \
# Termo_pesquisado
# analista de dados                   269     115           383       383
# analista de negocios                205       0           205       205
# analista de negocios                  0     654           654       654
# business analytics                    5      12            17        17
# business inteligence                  4       4             8         8
# cientista de dados                   67      88           104       104
# data analytics                       27       2            27        27
# data analytics                        0      44            44        44
# data science                         12      52            62        62
# data scientist                        1       1             1         1
# engenheiro de dados                  44       0            44        44
# engenheiro de dados                   0      27            27        27
# engenheiro de machine learning        2       6             8         8
# inteligencia de dados                 1       1             1         1
# inteligencia de negocios             44      39            83        83
# people analytics                      2       2             2         2
#
#                                 Longitude
# Termo_pesquisado
# analista de dados                     383
# analista de negocios                  205
# analista de negocios                  654
# business analytics                     17
# business inteligence                    8
# cientista de dados                    104
# data analytics                         27
# data analytics                         44
# data science                           62
# data scientist                          1
# engenheiro de dados                    44
# engenheiro de dados                    27
# engenheiro de machine learning          8
# inteligencia de dados                   1
# inteligencia de negocios               83
# people analytics                        2

# %%
df = df.append({'Termo_pesquisado':'paulo pedro', 'Competências': my_text}, ignore_index=True)
df = df.append({'Termo_pesquisado':'paulo pedro', 'Competências': my_text}, ignore_index=True)
df = df.append({'Termo_pesquisado':'paulo pedro', 'Competências': my_text}, ignore_index=True)
df = df.append({'Termo_pesquisado':'paulo pedro', 'Competências': my_text}, ignore_index=True)
df = df.append({'Termo_pesquisado':'paulo pedro', 'Competências': my_text}, ignore_index=True)

# %%
termo_pesquisado = [
                    'cientista_de_dados',
                    'data_science',
                    'data_analytics',
                    'engenheiro_de_machine_learning',
                    'analista_de_dados',
                    'engenheiro_de_dados',
                    'business_inteligence',
                    'business_analytics',
                    'analista_de_negocios',
                    'inteligencia_de_negocios'
                    ]

# %%
#termo1 = termo_pesquisado[0]
#termo2 = termo_pesquisado[1]
    
#df_science = df.loc[(df['Termo_pesquisado'] == termo)]
#df_analise = df.loc[(df['Termo_pesquisado'] == termo1) | (df['Termo_pesquisado'] == termo2)]
df_analise = df.copy()

# %%
df_analise.groupby(['Termo_pesquisado']).count()
# Out:
#                                 Cidade  Competências  Descrição_da_empresa  \
# Termo_pesquisado
# analista de dados                  383           383                   186
# analista de negocios               205           205                   145
# analista de negocios               654           654                     0
# business analytics                  17            17                     4
# business inteligence                 8             8                     3
# cientista de dados                 104           104                    12
# data analytics                      27            27                    19
# data analytics                      44            44                     0
# data science                        62            62                     8
# data scientist                       1             1                     0
# engenheiro de dados                 44            44                    27
# engenheiro de dados                 27            27                     0
# engenheiro de machine learning       8             8                     1
# inteligencia de dados                1             1                     0
# inteligencia de negocios            83            83                    27
# paulo pedro                          0             5                     0
# people analytics                     2             2                     0
#
#                                 Empresa  Estado  Nome_da_vaga  Latitude  \
# Termo_pesquisado
# analista de dados                   269     115           383       383
# analista de negocios                205       0           205       205
# analista de negocios                  0     654           654       654
# business analytics                    5      12            17        17
# business inteligence                  4       4             8         8
# cientista de dados                   67      88           104       104
# data analytics                       27       2            27        27
# data analytics                        0      44            44        44
# data science                         12      52            62        62
# data scientist                        1       1             1         1
# engenheiro de dados                  44       0            44        44
# engenheiro de dados                   0      27            27        27
# engenheiro de machine learning        2       6             8         8
# inteligencia de dados                 1       1             1         1
# inteligencia de negocios             44      39            83        83
# paulo pedro                           0       0             0         0
# people analytics                      2       2             2         2
#
#                                 Longitude
# Termo_pesquisado
# analista de dados                     383
# analista de negocios                  205
# analista de negocios                  654
# business analytics                     17
# business inteligence                    8
# cientista de dados                    104
# data analytics                         27
# data analytics                         44
# data science                           62
# data scientist                          1
# engenheiro de dados                    44
# engenheiro de dados                    27
# engenheiro de machine learning          8
# inteligencia de dados                   1
# inteligencia de negocios               83
# paulo pedro                             0
# people analytics                        2

# %%
nlp = spacy.load('pt')

# %%
punctuations = string.punctuation
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
words = nlp(u'pablo stanger etc de a o que e do da em um para é com não uma os no se na por mais as dos como mas foi ao ele das tem à seu sua ou ser quando muito há nos já está eu também só pelo pela até isso ela entre era depois sem mesmo aos ter seus quem nas me esse eles estão você tinha foram essa num nem suas meu às minha têm numa pelos elas havia seja qual será nós tenho lhe deles essas esses pelas este fosse dele tu te vocês vos lhes meus minhas teu tua teus tuas nosso nossa nosso nossas dela delas esta estes estas aquele aquela aqueles aquelas isto aquilo estou está estamos estão estive esteve estivemos estiveram estava estávamos estavam estivera estivéramos esteja estejamos estejam estivesse estivéssemos estivessem estiver estivermos estiverem hei há havemos hão houve houvemos houveram houvera houvéramos haja hajamos hajam houvesse houvéssemos houvessem houver houvermos houverem houverei houverá houveremos houverão houveria houveríamos houveriam sou somos são era éramos eram fui foi fomos foram fora fôramos seja sejamos sejam fosse fôssemos fossem for formos forem serei será seremos serão seria seríamos seriam tenho tem temos tém tinha tínhamos tinham tive teve tivemos tiveram tivera tivéramos tenha tenhamos tenham tivesse tivéssemos tivessem tiver tivermos tiverem terei terá teremos terão teria teríamos teriam')
#words_sem_de = nlp(u'a o que e do da em um para é com não uma os no se na por mais as dos como mas foi ao ele das tem à seu sua ou ser quando muito há nos já está eu também só pelo pela até isso ela entre era depois sem mesmo aos ter seus quem nas me esse eles estão você tinha foram essa num nem suas meu às minha têm numa pelos elas havia seja qual será nós tenho lhe deles essas esses pelas este fosse dele tu te vocês vos lhes meus minhas teu tua teus tuas nosso nossa nosso nossas dela delas esta estes estas aquele aquela aqueles aquelas isto aquilo estou está estamos estão estive esteve estivemos estiveram estava estávamos estavam estivera estivéramos esteja estejamos estejam estivesse estivéssemos estivessem estiver estivermos estiverem hei há havemos hão houve houvemos houveram houvera houvéramos haja hajamos hajam houvesse houvéssemos houvessem houver houvermos houverem houverei houverá houveremos houverão houveria houveríamos houveriam sou somos são era éramos eram fui foi fomos foram fora fôramos seja sejamos sejam fosse fôssemos fossem for formos forem serei será seremos serão seria seríamos seriam tenho tem temos tém tinha tínhamos tinham tive teve tivemos tiveram tivera tivéramos tenha tenhamos tenham tivesse tivéssemos tivessem tiver tivermos tiverem terei terá teremos terão teria teríamos teriam')
words = [token.orth_ for token in words if not token.is_punct]
stopwords = frozenset(words)

# %%
words_ingles = nlp(u"bairesdev is seeking a tech lead to work with some of our most important clients in usa and europe. be part of an extraordinary opportunity to transform the higher experience! what we need? bairesdev is looking for a seasoned tech lead to join a stellar team working on it marketplace industry across the world. you will work with the developer and deliver & maintain critical software to serve clients, front office, and the general community to ensure excellent customer service experiences for all internal and external customers. you will have the opportunity to work on projects for companies that make a difference in each category. what we can offer you: one of our core values at bairesdev is to recognise and reward our staff as our greatest asset. we realise that it\'s our people who have built our outstanding reputation and that we will only maintain our leading position in the it world by continuing to attract and retain talented and motivated people. if you choose to come and work with us, you will find that we offer: excellent benefits and salary. a welcoming and inclusive environment. extensive development opportunities. stunning surroundings. remote work if this sounds great to you, please apply now. experience working with data scientist technology. experience business in software engineering. bairesdev is looking for a data scientist ssr/sr developer to work for a very important client in usa. this is a great opportunity for someone to be part of a rapid growth of a close knit team. this job offer is for full time and long term engagement, and you are allowed to work from your home. we love the rockstars, the self-taught geniuses, the niche specialists who know things almost no one knows. we love heads-down producers, the imaginative renegades, the go-to veterans who know what they know inside out. what we can offer you. one of our core values at bairesdev is to recognize and reward our staff as our greatest asset. we realise that it's our people who have built our outstanding reputation and that we will only maintain our leading position in the it world by continuing to attract and retain talented and motivated people. if you choose to come and work with us, you will find that we offer: excellent benefits and salary. a welcoming and inclusive environment. extensive development opportunities the minimum requirements are: data scientist experience working as a developer. proficient with analysis, troubleshooting, and problem solving. hands-on experience with managing data loads and data quality a plus. advanced english is mandatory")
words_ingles = [token.orth_ for token in words_ingles if not token.is_punct]
stopwords_ingles = frozenset(words_ingles)

# %%
df_analise['Termo_pesquisado'].replace(' ', '_', regex=True, inplace=True)
df_analise['Cidade'].replace(' ', '_', regex=True, inplace=True)
df_analise['Estado'].replace(' ', '_', regex=True, inplace=True)
df_analise = df_analise.assign(ConteudoTotal =  
                               df_analise['Termo_pesquisado'].astype(str) + ' ' +
#                               df_analise['Cidade'].astype(str) + ' ' +
#                               df_analise['Estado'].astype(str) + ' ' +
                               df_analise.Competências.astype(str))

# Select features from original dataset to form a new dataframe 
#>>> df1 = df[['Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category','Vehicle Size', 'Vehicle Style', 'Maker_Model']]
# For each row, combine all the columns into one column
#>>> df2 = df1.apply(lambda x: ','.join(x.astype(str)), axis=1)
# Store them in a pandas dataframe
#>>> df_clean = pd.DataFrame({'clean': df2})
# Create the list of list format of the custom corpus for gensim modeling 
#>>> sent = [row.split(',') for row in df_clean['clean']]
# show the example of list of list format of the custom corpus for gensim modeling 
#>>> sent[:2]
#[['premium unleaded (required)',
#  'MANUAL',
#  'rear wheel drive',
#  'Factory Tuner',
#  'Luxury',
#  'High-Performance',
#  'Compact',
#  'Coupe',
#  'BMW 1 Series M'],
# ['premium unleaded (required)',
#  'MANUAL',
#  'rear wheel drive',
#  'Luxury',
#  'Performance',
#  'Compact',
#  'Convertible',
#  'BMW 1 Series']]

# %%
df_analise.ConteudoTotal
# Out:
# 0       cientista_de_dados o cientista de dados ou dat...
# 1       cientista_de_dados utilizar modelos matematico...
# 2       cientista_de_dados interpretacao de tendencias...
# 3       cientista_de_dados modelar problemas complexos...
# 4       cientista_de_dados realizar projetos sprint de...
# 5       cientista_de_dados desenvolvimento de software...
# 6       cientista_de_dados sprints adicionais / avulso...
# 7       cientista_de_dados modelar problemas complexos...
# 8       cientista_de_dados empresa   referencia em dat...
# 9       cientista_de_dados sera sua responsabilidade o...
# 10      cientista_de_dados *curso superior completo em...
# 11      cientista_de_dados programacao, de preferencia...
# 12      cientista_de_dados organizar e validar os dado...
# 13      cientista_de_dados adquirir, avaliar e process...
# 14      cientista_de_dados transformar as fontes de da...
# 15      cientista_de_dados - solucionar problemas de n...
# 16      cientista_de_dados ira atuar com ambientes de ...
# 17      cientista_de_dados para fazer parte desse supe...
# 18      cientista_de_dados considerado a nova geracao ...
# 19      cientista_de_dados projetar, implementar e sup...
# 20      cientista_de_dados resolver problemas complexo...
# 21      cientista_de_dados atuar com metodos de modela...
# 22      cientista_de_dados especialistas em analise de...
# 23      cientista_de_dados desenvolver novas campanhas...
# 24      cientista_de_dados identificar, avaliar a rele...
# 25      cientista_de_dados desenvolver novas campanhas...
# 26      cientista_de_dados lidar com volume de dados d...
# 27      cientista_de_dados tecnicas de machine learnin...
# 28      cientista_de_dados gigante nacional, atuante d...
# 29      cientista_de_dados a stefanini labs, celula de...
# 30      cientista_de_dados desenvolver modelos estatis...
# 31      cientista_de_dados levantamento e documentacao...
# 32      cientista_de_dados responsavel pelo pesquisa, ...
# 33      cientista_de_dados atuar com mineracao de dado...
# 34      cientista_de_dados mindset empreendedor, ter p...
# 35      cientista_de_dados projetar e implementar mode...
# 36      cientista_de_dados o cientista de dados e uma ...
# 37      data_science bairesdev is seeking a data scien...
# 38      data_science bairesdev is looking for a data s...
# 39      data_science atuar em atividades especificas q...
# 40      data_science para mais informacoes e candidatu...
# 41      data_science mapear regras de negocio; gerar m...
# 42      data_science buscamos um profissional com soli...
# 43      data_science ira atuar diretamente em data- dr...
# 44      data_science atuara no apoio as equipes de pro...
# 45      data_science desenvolver produtos inovadores d...
# 46      data_science configuracao de formularios para ...
# 47      data_science experiencia com banco de dados re...
# 48      data_science automatizar e monitorar o process...
# 49      data_science realizar atendimentos de demandas...
# 50      data_science mapear dados disponiveis em relat...
# 51      data_science tuar na customizacao de projetos ...
# 52      data_science desenvolver processos de etl util...
# 53      data_science responsavel direto pela modelagem...
# 54      data_science atuar com programacao, codificaca...
# 55      data_science aplicar uma ampla gama de tecnica...
# 56      data_science as a data scientist at catho/seek...
# 57      data_science liderar projetos / equipes de cie...
# 58      data_science tratamento estatistico de dados (...
# 59      data_science atuacao com analytcs, extracao e ...
# 60      data_science desenhar, arquitetar, planejar e ...
# 61      data_science nos somos uma startup de tecnolog...
# 62      data_science ter atuado com datamining, estoca...
# 63      data_science estamos a procura de um cientista...
# 64      data_science atento e a multinacional de servi...
# 65      data_science atuar com plataforma salesforce, ...
# 66      data_science analisar jornadas do cliente celc...
# 67      data_science temos uma oportunidade para atuar...
# 68      data_science construir sistemas inteligentes q...
# 69      data_science elaboracao das documentacoes func...
# 70      data_science atuar com consultoria do python e...
# 71      data_science experiencia como scrum master em ...
# 72      data_science realizar o processo de recrutamen...
# 73      data_science arquitetar sistemas distribuidos,...
# 74      data_science o profissional ira atuar com as a...
# 75      data_science analise e acompanhamento dos indi...
# 76      data_science trabalhar na coleta, armazenament...
# 77      data_science trabalhar na coleta, armazenament...
# 78      data_science trabalhar na coleta, armazenament...
# 79      data_science trabalhar na coleta, armazenament...
# 80      data_science trabalhar na coleta, armazenament...
# 81      data_science apoiar equipe de planejamento com...
# 82      data_science criar e validar hipoteses de nego...
# 83      data_science desejo de balancear teoria com ha...
# 84      data_science aplicar os seus talentos e energi...
# 85      data_science o profissional ira vivenciar a op...
# 86      data_science mapear dados disponiveis em relat...
# 87      data_analytics_ ferramentas e metodos tecnolog...
# 88      data_analytics_ conhecimento comprovado em goo...
# 89      data_analytics_ realizar a implantacao e desen...
# 90      data_analytics_ gerenciar projetos de tecnolog...
# 91      data_analytics_ fazer a gestao da equipe de an...
# 92      data_analytics_ atuar com tecnologia da inform...
# 93      data_analytics_ analise diaria do desempenho d...
# 94      data_analytics_ elaboracao e implementacao de ...
# 95      data_analytics_ elaboracao e implementacao de ...
# 96      data_analytics_ analise diaria do desempenho d...
# 97      data_analytics_ sera responsavel pelo gerencia...
# 98      data_analytics_ ira desenvolver atividades per...
# 99      data_analytics_ atuar com venda tecnica, abord...
# 100     data_analytics_ to strengthen our product deve...
# 101     data_analytics_ to strengthen our product deve...
# 102     data_analytics_ ser responsavel pelo contato e...
# 103     data_analytics_ o profissional sera responsave...
# 104     data_analytics_ modernizacao de sistemas utili...
# 105     data_analytics_ atuar com projetos com linguag...
# 106     data_analytics_ arquiteto de solucoes big data...
# 107     data_analytics_ realizar as atividades relacio...
# 108     data_analytics_ gerir e desenvolver nossos can...
# 109     data_analytics_ funcional que ira fazer toda i...
# 110     data_analytics_ ser o responsavel por desenvol...
# 111     data_analytics_ ser o responsavel por desenvol...
# 112     data_analytics_ atribuicoes: ser o responsavel...
# 113     data_analytics_ oportunidade essence? consulto...
# 114     data_analytics_ atuar com programacao de plant...
# 115     data_analytics_ atuar com azure data lake, azu...
# 116     data_analytics_ tera como responsabilidade a a...
# 117     data_analytics_ organizacao de feiras e outros...
# 118     data_analytics_ melhorar o processo de tomada ...
# 119     data_analytics_ analise e geracao de insights ...
# 120     data_analytics_ atividades: entendimento da ar...
# 121     data_analytics_ the latam roomit performance m...
# 122     data_analytics_ oportunidade essence, consulto...
# 123     data_analytics_ desenhar, programar, desenvolv...
# 124     data_analytics_ desenvolver e manter data ware...
# 125     data_analytics_ trabalhar em projetos de intel...
# 126     data_analytics_ trabalhar em projetos de integ...
# 127     data_analytics_ responsabilidade analisar os i...
# 128     data_analytics_ executar os trabalhos complexo...
# 129     data_analytics_ conduzir as atividades sujeita...
# 130     data_analytics_ your key responsibilities will...
# 131     engenheiro_de_machine_learning implementacao d...
# 132     engenheiro_de_machine_learning transformacao d...
# 133     engenheiro_de_machine_learning o engenheiro de...
# 134     engenheiro_de_machine_learning selecionamos pr...
# 135     engenheiro_de_machine_learning about escale es...
# 136     engenheiro_de_machine_learning orientar e trab...
# 137     analista_de_dados criar e consultar banco de d...
# 138     analista_de_dados modelagem de estruturas de i...
# 139     analista_de_dados desenvolver e implantar sist...
# 140     analista_de_dados atuar com analise de process...
# 141     analista_de_dados administrar banco de dados o...
# 142     analista_de_dados responsavel por analisar e p...
# 143     analista_de_dados atuar com modelagem de banco...
# 144     analista_de_dados instalar e aplicar correcoes...
# 145     analista_de_dados ira  desenvolver, implementa...
# 146     analista_de_dados atuacao como dba em demandas...
# 147     analista_de_dados ira atuar com a centralizaca...
# 148     analista_de_dados estamos em busca de um (a) a...
# 149     analista_de_dados integralizacao de sistemas, ...
# 150     analista_de_dados atuar com conversao de dados...
# 151     analista_de_dados atuara na elaboracao de dash...
# 152     analista_de_dados realizacao de desenvolviment...
# 153     analista_de_dados realiza as fases de elaborac...
# 154     analista_de_dados administrar, auxiliar a impl...
# 155     analista_de_dados administrador de banco de da...
# 156     analista_de_dados tecnologia da informacao. ad...
# 157     analista_de_dados requisitos obrigatorios:\r\r...
# 158     analista_de_dados ira coletar informacoes das ...
# 159     analista_de_dados atuar com desenvolvimento de...
# 160     analista_de_dados realizar tarefas a serem des...
# 161     analista_de_dados atuar principalmente no dese...
# 162     analista_de_dados a sinqia e focada em criar e...
# 163     analista_de_dados atuar com mapeamento de proc...
# 164     analista_de_dados criar estruturas de banco de...
# 165     analista_de_dados dominio em banco de dados: p...
# 166     analista_de_dados extrair insights de negocio ...
# 167     analista_de_dados responsavel pelas demandas, ...
# 168     analista_de_dados este profissional atuara em ...
# 169     analista_de_dados atuar com extracao de dados ...
# 170     analista_de_dados levantamento e analise de da...
# 171     analista_de_dados analisar bases de dados, pre...
# 172     analista_de_dados configurar e manter a infrae...
# 173     analista_de_dados realiza servicos nos equipam...
# 174     analista_de_dados gerenciamento de servidores,...
# 175     analista_de_dados desenvolvimento de solucoes,...
# 176     analista_de_dados atuar com criacao de rotinas...
# 177     analista_de_dados acompanhamento na definicao ...
# 178     analista_de_dados ficara responsavel por levan...
# 179     analista_de_dados levantar as necessidades dos...
# 180     analista_de_dados levantar as necessidades dos...
# 181     analista_de_dados identificar as oportunidades...
# 182     analista_de_dados atuar na area de omni channe...
# 183     analista_de_dados otimizacao tatica mensal de ...
# 184     analista_de_dados profissional sera responsave...
# 185     analista_de_dados atuar na estrategia de novas...
# 186     analista_de_dados extrair e analisar as bases ...
# 187     analista_de_dados implementar e manter os banc...
# 188     analista_de_dados desenvolvedor oracle pl sql,...
# 189     analista_de_dados administra banco de dados, e...
# 190     analista_de_dados necessario conhecimento em d...
# 191     analista_de_dados demonstrar capacidade de con...
# 192     analista_de_dados administracao de banco de da...
# 193     analista_de_dados ira atuar com c#, javascript...
# 194     analista_de_dados administra banco de dados, e...
# 195     analista_de_dados administra banco de dados, e...
# 196     analista_de_dados voce ama tecnologia e quer f...
# 197     analista_de_dados - catalogacao de dados, linh...
# 198     analista_de_dados atuar em analise de dados, d...
# 199     analista_de_dados coletar dados dos clientes d...
# 200     analista_de_dados atuar no nosso nucleo de int...
# 201     analista_de_dados administrar banco de dados, ...
# 202     analista_de_dados alocacao em cliente, atuacao...
# 203     analista_de_dados o profissional que tera como...
# 204     analista_de_dados suporte a producao durante o...
# 205     analista_de_dados analise de resultados do pro...
# 206     analista_de_dados identificar as oportunidades...
# 207     analista_de_dados desenvolver etl. fazer integ...
# 208     analista_de_dados entender as regras de negoci...
# 209     analista_de_dados fazer acompanhamento de estu...
# 210     analista_de_dados experiencia e participacao e...
# 211     analista_de_dados atuara na manutencao de etl ...
# 212     analista_de_dados a essence e uma consultoria ...
# 213     analista_de_dados medir, controlar, monitorar ...
# 214     analista_de_dados o instrutor principal sera r...
# 215     analista_de_dados gerenciar backups fisicos e ...
# 216     analista_de_dados ira atuar em infra-estrutura...
# 217     analista_de_dados atuar com desenvolvimento de...
# 218     analista_de_dados a sinqia e focada em criar e...
# 219     analista_de_dados ira elaborar consultas em li...
# 220     analista_de_dados acompanhamento e desenvolvim...
# 221     analista_de_dados - estruturar objetos em banc...
# 222     analista_de_dados ? apoiar a organizacao e imp...
# 223     analista_de_dados experiencia em db schemas e ...
# 224     analista_de_dados planejar e executar a admini...
# 225     analista_de_dados atuar em atualizacao de vers...
# 226     analista_de_dados realizar atendimento aos cli...
# 227     analista_de_dados atuar com administracao e mo...
# 228     analista_de_dados analise de codigo sql para s...
# 229     analista_de_dados atuar com gestao das ferrame...
# 230     analista_de_dados experiencia em governanca de...
# 231     analista_de_dados analise e desenvolvimento de...
# 232     analista_de_dados atuar com administracao de b...
# 233     analista_de_dados atividades: - atuar como des...
# 234     analista_de_dados a sinqia e focada em criar e...
# 235     analista_de_dados suportar o core business com...
# 236     analista_de_dados demonstrar capacidade de con...
# 237     analista_de_dados responsavel por identificar,...
# 238     analista_de_dados foco na administracao (dba) ...
# 239     analista_de_dados analise e desenvolvimento de...
# 240     analista_de_dados mapear os riscos de credito ...
# 241     analista_de_dados atuara como analista de banc...
# 242     analista_de_dados fazendo parte do nosso time ...
# 243     analista_de_dados entender e identificar as ne...
# 244     analista_de_dados gestao e manutencao de maqui...
# 245     analista_de_dados instalacao, administracao e ...
# 246     analista_de_dados gestao e manutencao de maqui...
# 247     analista_de_dados realizar manutencao de instr...
# 248     analista_de_dados atua com linguagem de progra...
# 249     analista_de_dados atuar com gerenciamento de b...
# 250     analista_de_dados adora montar dashboards comp...
# 251     engenheiro_de_dados_ o que esperamos em voce:\...
# 252     engenheiro_de_dados_ trabalhar com administrac...
# 253     engenheiro_de_dados_ atuara com analise de dad...
# 254     engenheiro_de_dados_ atuar com conhecimento em...
# 255     engenheiro_de_dados_ sera responsavel pelo arm...
# 256     engenheiro_de_dados_ ser responsavel pelo gere...
# 257     engenheiro_de_dados_ atuar com cloudera hadoop...
# 258     engenheiro_de_dados_ atuar no time de analytic...
# 259     engenheiro_de_dados_ criar pipelines escalavei...
# 260     engenheiro_de_dados_ atuar com ferramentas (sp...
# 261     engenheiro_de_dados_ criar pipelines de dados ...
# 262     engenheiro_de_dados_ coleta, combinacao e disp...
# 263     engenheiro_de_dados_ tratamento, extracao e an...
# 264     engenheiro_de_dados_ preparacao e tratamentos ...
# 265     engenheiro_de_dados_ atuar como scrum master n...
# 266     engenheiro_de_dados_ atuara com analise de dad...
# 267     engenheiro_de_dados_ desenvolve softwares e ap...
# 268     engenheiro_de_dados_ realizar ingestao de dado...
# 269     engenheiro_de_dados_ desenvolvimento orientado...
# 270     engenheiro_de_dados_ desenvolvimento avancado ...
# 271     engenheiro_de_dados_ atuara na modelagem, gest...
# 272     engenheiro_de_dados_ cultura devops (fazer par...
# 273     engenheiro_de_dados_ participar ativamente no ...
# 274     engenheiro_de_dados_ trabalhar com estrutura d...
# 275     engenheiro_de_dados_ coleta, combinacao e disp...
# 276     engenheiro_de_dados_ atuar com capacidade anal...
# 277     engenheiro_de_dados_ atuar com preparacao e tr...
# 278     business_inteligence atuar com  modelagem de d...
# 279     business_inteligence o profissional conduzira ...
# 280     business_inteligence responder duvidas e forne...
# 281     business_inteligence desenvolvimento de sistem...
# 282     business_analytics levantamento de atividades ...
# 283     business_analytics somos referencia nacional e...
# 284     business_analytics as a business analyst, you ...
# 285     business_analytics responsavel por gerar anali...
# 286     business_analytics responsavel por gerar anali...
# 287     business_analytics o que precisamos e o que de...
# 288     business_analytics o que precisamos e o que de...
# 289     business_analytics sera responsavel por extrai...
# 290     business_analytics atuar na area de business i...
# 291     business_analytics lideranca da equipe tecnica...
# 292     business_analytics lideranca da equipe tecnica...
# 293     business_analytics desenvolver modelagem de da...
# 294     analista_de_negocios_ atuar com vendas de fran...
# 295     analista_de_negocios_ acompanhar os usuarios n...
# 296     analista_de_negocios_ apoio no desenvolvimento...
# 297     analista_de_negocios_ realizar suporte ao admi...
# 298     analista_de_negocios_ realiza atividades para ...
# 299     analista_de_negocios_ suporte comercial de ate...
# 300     analista_de_negocios_ realizar atendimento ao ...
# 301     analista_de_negocios_ prospeccao de alunos, de...
# 302     analista_de_negocios_ executar as atividades d...
# 303     analista_de_negocios_ responsavel por toda a t...
# 304     analista_de_negocios_ facilitar e auxiliar o c...
# 305     analista_de_negocios_ acompanhar etapa de comp...
# 306     analista_de_negocios_ realizar o acompanhament...
# 1602    inteligencia_de_negocios requisitos para selec...
# 1603    inteligencia_de_negocios descricao das ativida...
# 1604    inteligencia_de_negocios desenvolver equipe, p...
# 1605    inteligencia_de_negocios responsavel pela area...
# 1606    inteligencia_de_negocios nessa posicao, voce s...
# 1607    inteligencia_de_negocios atividades e responsa...
# 1608    inteligencia_de_negocios definicao e desenvolv...
# 1609    data_science venha transformar a educacao com ...
# 1610    data_science como coordenador de data science,...
# 1611    cientista_de_dados cientista de dados / desenv...
# 1612    cientista_de_dados temos a missao de manter e ...
# 1613    cientista_de_dados cientista de dados para ver...
# 1614    cientista_de_dados buscamos profissional para ...
# 1615    data_scientist procuramos talentos com garra e...
# 1616    people_analytics como desenvolvedor back end o...
# 1617    people_analytics oportunidade para estagiar na...
# 1618    data_analytics the business and data analytics...
# 1619    data_analytics auditor pleno de sistemas e dat...
# 1620    analista_de_dados para contribuir com evidenci...
# 1621    analista_de_dados na zenvia buscamos incessant...
# 1622    inteligencia_de_dados empresa do ramo de terce...
# 1623    cientista_de_dados requisitos e qualificacoes:...
# 1624    cientista_de_dados requisitos e qualificacoes:...
# 1625    cientista_de_dados who you are: university deg...
# 1626    cientista_de_dados o que buscamos? pessoas que...
# 1627    cientista_de_dados perfil desejado: formacao c...
# 1628    cientista_de_dados quais sao os requisitos esp...
# 1629    cientista_de_dados requisitos mandatorios: ing...
# 1630    cientista_de_dados requisitos e qualificacoes:...
# 1631    cientista_de_dados voce precisa: conhecer bem ...
# 1632    cientista_de_dados requisitos obrigatorios: gr...
# 1633    cientista_de_dados escolaridade: graduacao em ...
# 1634    cientista_de_dados pre-requisitos: graduacao e...
# 1635    cientista_de_dados requisitos necessarios: con...
# 1636    cientista_de_dados requerido: python; sql serv...
# 1637    cientista_de_dados habilidades obrigatorias: s...
# 1638    cientista_de_dados habilidades obrigatorias: w...
# 1639    cientista_de_dados esta e uma vaga de um clien...
# 1640    cientista_de_dados habilidades e requisitos ex...
# 1641    cientista_de_dados as habilidades que sao espe...
# 1642    cientista_de_dados requisitos: dominio nas lin...
# 1643    cientista_de_dados para ser cientista de dados...
# 1644    cientista_de_dados o que buscamos: solida form...
# 1645    cientista_de_dados quais serao os seus desafio...
# 1646    cientista_de_dados exigencias da vaga: afinida...
# 1647    cientista_de_dados requisitos: conhecimento e ...
# 1648    cientista_de_dados requisitos: experiencia em ...
# 1649    cientista_de_dados habilidades tecnicas: ter m...
# 1650    cientista_de_dados requisitos: superior comple...
# 1651    cientista_de_dados para fazer parte desse supe...
# 1652    cientista_de_dados e o que e necessario para e...
# 1653    cientista_de_dados requisitos: graduacao em um...
# 1654    cientista_de_dados requisitos do cargo: habili...
# 1655    cientista_de_dados matematica: algebra linear,...
# 1656    cientista_de_dados requisitos e qualificacoes:...
# 1657    cientista_de_dados requisitos imprescindiveis:...
# 1658    cientista_de_dados curso superior completo em ...
# 1659    cientista_de_dados para essa oportunidade, pre...
# 1660    cientista_de_dados a sinqia e focada em criar ...
# 1661    cientista_de_dados o que voce traz? experienci...
# 1662    cientista_de_dados necessario conhecimento nas...
# 1663    cientista_de_dados atividades da vaga: coleta ...
# 1664    cientista_de_dados o que buscamos? procuramos ...
# 1665    cientista_de_dados perfil do candidato: estamo...
# 1666    cientista_de_dados coordene a equipe de data s...
# 1667    cientista_de_dados conhecimentos: conhecimento...
# 1668    cientista_de_dados requirements and skills: 1....
# 1669    cientista_de_dados skills: solido conhecimento...
# 1670    paulo_pedro Pablo Stanger\n\nFone: (55-11) 971...
# 1671    paulo_pedro Pablo Stanger\n\nFone: (55-11) 971...
# 1672    paulo_pedro Pablo Stanger\n\nFone: (55-11) 971...
# 1673    paulo_pedro Pablo Stanger\n\nFone: (55-11) 971...
# 1674    paulo_pedro Pablo Stanger\n\nFone: (55-11) 971...
# Name: ConteudoTotal, dtype: object

# %%
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    # txt = [token.lemma_ for token in doc if not token.is_stop]
    txt = [token for token in doc]
#    txt = [token.lemma_ for token in txt]
    txt = [token.orth_ for token in txt]
    # txt = [token for token in txt if (token not in stopwords and token not in punctuations)]
    txt = [token for token in txt if (token not in stopwords and token not in stopwords_ingles)]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %%
#brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df2) #REGEX
brief_cleaning = (re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^`{|}~]', ' ', str(row)).lower() for row in df_analise.ConteudoTotal) #REGEX

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 3.99 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
#df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (1675, 1)

# %%
df_clean['clean']
# Out:
# 0       cientista_de_dados cientista dados considerado...
# 1       cientista_de_dados utilizar modelos matematico...
# 2       cientista_de_dados interpretacao tendencias   ...
# 3       cientista_de_dados modelar problemas complexos...
# 4       cientista_de_dados realizar projetos sprint de...
# 5       cientista_de_dados desenvolvimento   ajudar co...
# 6       cientista_de_dados sprints adicionais    avuls...
# 7       cientista_de_dados modelar problemas complexos...
# 8       cientista_de_dados empresa    referencia drive...
# 9       cientista_de_dados sera responsabilidade levan...
# 10      cientista_de_dados   curso superior completo e...
# 11      cientista_de_dados programacao   preferencia p...
# 12      cientista_de_dados organizar validar dados ger...
# 13      cientista_de_dados adquirir   avaliar processa...
# 14      cientista_de_dados transformar fontes dados in...
# 15      cientista_de_dados    solucionar problemas neg...
# 16      cientista_de_dados ira atuar ambientes alta cr...
# 17      cientista_de_dados fazer parte super   precisa...
# 18      cientista_de_dados considerado nova geracao es...
# 19      cientista_de_dados projetar   implementar supo...
# 20      cientista_de_dados resolver problemas complexo...
# 21      cientista_de_dados atuar metodos modelagem ana...
# 22      cientista_de_dados especialistas analise dados...
# 23      cientista_de_dados desenvolver novas campanhas...
# 24      cientista_de_dados identificar   avaliar relev...
# 25      cientista_de_dados desenvolver novas campanhas...
# 26      cientista_de_dados lidar volume dados diversas...
# 27      cientista_de_dados tecnicas machine learning  ...
# 28      cientista_de_dados gigante nacional   atuante ...
# 29      cientista_de_dados stefanini labs   celula ino...
# 30      cientista_de_dados desenvolver modelos estatis...
# 31      cientista_de_dados levantamento documentacao r...
# 32      cientista_de_dados responsavel pesquisa   gere...
# 33      cientista_de_dados atuar mineracao dados   min...
# 34      cientista_de_dados mindset empreendedor   post...
# 35      cientista_de_dados projetar implementar modelo...
# 36      cientista_de_dados cientista dados funcao area...
# 37      data_science                        it\       ...
# 38      data_science           self taught     heads d...
# 39      data_science atuar atividades especificas exig...
# 40      data_science informacoes candidatura   acesse ...
# 41      data_science mapear regras negocio   gerar mod...
# 42      data_science buscamos profissional solidos con...
# 43      data_science ira atuar diretamente   driven   ...
# 44      data_science atuara apoio equipes produto   ve...
# 45      data_science desenvolver produtos inovadores i...
# 46      data_science configuracao formularios entrada ...
# 47      data_science experiencia banco dados relaciona...
# 48      data_science automatizar monitorar processo in...
# 49      data_science realizar atendimentos demandas ex...
# 50      data_science mapear dados disponiveis relatori...
# 51      data_science tuar customizacao projetos gestao...
# 52      data_science desenvolver processos etl utiliza...
# 53      data_science responsavel direto modelagem desc...
# 54      data_science atuar programacao   codificacao a...
# 55      data_science aplicar ampla gama tecnicas teori...
# 56      data_science catho seek responsible  \r\r\n\r\...
# 57      data_science liderar projetos    equipes cienc...
# 58      data_science tratamento estatistico dados   mi...
# 59      data_science atuacao analytcs   extracao trata...
# 60      data_science desenhar   arquitetar   planejar ...
# 61      data_science startup tecnologia facilita fluxo...
# 62      data_science atuado datamining   estocasticos ...
# 63      data_science procura cientista dados ira apoia...
# 64      data_science atento multinacional servicos pro...
# 65      data_science atuar plataforma salesforce   esp...
# 66      data_science analisar jornadas cliente celcoin...
# 67      data_science oportunidade atuar analista polit...
# 68      data_science construir sistemas inteligentes a...
# 69      data_science elaboracao documentacoes funciona...
# 70      data_science atuar consultoria python sql   in...
# 71      data_science experiencia scrum master conducao...
# 72      data_science realizar processo recrutamento   ...
# 73      data_science arquitetar sistemas distribuidos ...
# 74      data_science profissional ira atuar atividades...
# 75      data_science analise acompanhamento indicadore...
# 76      data_science trabalhar coleta   armazenamento ...
# 77      data_science trabalhar coleta   armazenamento ...
# 78      data_science trabalhar coleta   armazenamento ...
# 79      data_science trabalhar coleta   armazenamento ...
# 80      data_science trabalhar coleta   armazenamento ...
# 81      data_science apoiar equipe planejamento visao ...
# 82      data_science criar validar hipoteses negocio b...
# 83      data_science desejo balancear teoria habilidad...
# 84      data_science aplicar talentos energia criativa...
# 85      data_science profissional ira vivenciar oportu...
# 86      data_science mapear dados disponiveis relatori...
# 87      data_analytics _ ferramentas metodos tecnologi...
# 88      data_analytics _ conhecimento comprovado googl...
# 89      data_analytics _ realizar implantacao desenvol...
# 90      data_analytics _ gerenciar projetos tecnologia...
# 91      data_analytics _ fazer gestao equipe analise d...
# 92      data_analytics _ atuar tecnologia informacao  ...
# 93      data_analytics _ analise diaria desempenho sit...
# 94      data_analytics _ elaboracao implementacao proj...
# 95      data_analytics _ elaboracao implementacao proj...
# 96      data_analytics _ analise diaria desempenho sit...
# 97      data_analytics _ sera responsavel gerenciament...
# 98      data_analytics _ ira desenvolver atividades pe...
# 99      data_analytics _ atuar venda tecnica   abordar...
# 100     data_analytics _ strengthen product cloud base...
# 101     data_analytics _ strengthen product cloud   ba...
# 102     data_analytics _ responsavel contato mesa trab...
# 103     data_analytics _ profissional sera responsavel...
# 104     data_analytics _ modernizacao sistemas utiliza...
# 105     data_analytics _ atuar projetos linguagens pro...
# 106     data_analytics _ arquiteto solucoes big   desc...
# 107     data_analytics _ realizar atividades relaciona...
# 108     data_analytics _ gerir desenvolver nossos cana...
# 109     data_analytics _ funcional ira fazer toda inte...
# 110     data_analytics _ responsavel desenvolver plata...
# 111     data_analytics _ responsavel desenvolver plata...
# 112     data_analytics _ atribuicoes   responsavel des...
# 113     data_analytics _ oportunidade essence   consul...
# 114     data_analytics _ atuar programacao planta prod...
# 115     data_analytics _ atuar azure lake   azure lake...
# 116     data_analytics _ tera responsabilidade avaliac...
# 117     data_analytics _ organizacao feiras outros tip...
# 118     data_analytics _ melhorar processo tomada deci...
# 119     data_analytics _ analise geracao insights part...
# 120     data_analytics _ atividades   entendimento are...
# 121     data_analytics _ latam roomit performance mana...
# 122     data_analytics _ oportunidade essence   consul...
# 123     data_analytics _ desenhar   programar   desenv...
# 124     data_analytics _ desenvolver manter warehouse ...
# 125     data_analytics _ trabalhar projetos inteligenc...
# 126     data_analytics _ trabalhar projetos integracao...
# 127     data_analytics _ responsabilidade analisar inv...
# 128     data_analytics _ executar trabalhos complexos ...
# 129     data_analytics _ conduzir atividades sujeitas ...
# 130     data_analytics _ key responsibilities   gather...
# 131     engenheiro_de_machine_learning implementacao s...
# 132     engenheiro_de_machine_learning transformacao d...
# 133     engenheiro_de_machine_learning engenheiro dado...
# 134     engenheiro_de_machine_learning selecionamos pr...
# 135     engenheiro_de_machine_learning about escale es...
# 136     engenheiro_de_machine_learning orientar trabal...
# 137     analista_de_dados criar consultar banco dados ...
# 138     analista_de_dados modelagem estruturas informa...
# 139     analista_de_dados desenvolver implantar sistem...
# 140     analista_de_dados atuar analise processos   an...
# 141     analista_de_dados administrar banco dados orac...
# 142     analista_de_dados responsavel analisar paramet...
# 143     analista_de_dados atuar modelagem banco dados ...
# 144     analista_de_dados instalar aplicar correcoes b...
# 145     analista_de_dados ira   desenvolver   implemen...
# 146     analista_de_dados atuacao dba demandas impleme...
# 147     analista_de_dados ira atuar centralizacao mode...
# 148     analista_de_dados busca     analista integraca...
# 149     analista_de_dados integralizacao sistemas   au...
# 150     analista_de_dados atuar conversao dados brutos...
# 151     analista_de_dados atuara elaboracao dashboards...
# 152     analista_de_dados realizacao desenvolvimento  ...
# 153     analista_de_dados realiza fases elaboracao req...
# 154     analista_de_dados administrar   auxiliar imple...
# 155     analista_de_dados administrador banco dados   ...
# 156     analista_de_dados tecnologia informacao   admi...
# 157     analista_de_dados requisitos obrigatorios \r\r...
# 158     analista_de_dados ira coletar informacoes ciru...
# 159     analista_de_dados atuar desenvolvimento sistem...
# 160     analista_de_dados realizar tarefas serem desen...
# 161     analista_de_dados atuar principalmente desenvo...
# 162     analista_de_dados sinqia focada criar implanta...
# 163     analista_de_dados atuar mapeamento processos  ...
# 164     analista_de_dados criar estruturas banco dados...
# 165     analista_de_dados dominio banco dados   postgr...
# 166     analista_de_dados extrair insights negocio atr...
# 167     analista_de_dados responsavel demandas   arqui...
# 168     analista_de_dados profissional atuara projetos...
# 169     analista_de_dados atuar extracao dados banco d...
# 170     analista_de_dados levantamento analise dados f...
# 171     analista_de_dados analisar bases dados   prepa...
# 172     analista_de_dados configurar manter infraestru...
# 173     analista_de_dados realiza servicos equipamento...
# 174     analista_de_dados gerenciamento servidores   b...
# 175     analista_de_dados desenvolvimento solucoes   a...
# 176     analista_de_dados atuar criacao rotinas   stor...
# 177     analista_de_dados acompanhamento definicao mod...
# 178     analista_de_dados ficara responsavel levantame...
# 179     analista_de_dados levantar necessidades usuari...
# 180     analista_de_dados levantar necessidades usuari...
# 181     analista_de_dados identificar oportunidades ba...
# 182     analista_de_dados atuar area omni channel empr...
# 183     analista_de_dados otimizacao tatica mensal mid...
# 184     analista_de_dados profissional sera responsave...
# 185     analista_de_dados atuar estrategia novas infor...
# 186     analista_de_dados extrair analisar bases dados...
# 187     analista_de_dados implementar manter bancos da...
# 188     analista_de_dados desenvolvedor oracle pl sql ...
# 189     analista_de_dados administra banco dados   env...
# 190     analista_de_dados necessario conhecimento dese...
# 191     analista_de_dados demonstrar capacidade conclu...
# 192     analista_de_dados administracao banco dados or...
# 193     analista_de_dados ira atuar c    javascript   ...
# 194     analista_de_dados administra banco dados   env...
# 195     analista_de_dados administra banco dados   env...
# 196     analista_de_dados voce ama tecnologia quer faz...
# 197     analista_de_dados    catalogacao dados   linha...
# 198     analista_de_dados atuar analise dados   desenv...
# 199     analista_de_dados coletar dados clientes escri...
# 200     analista_de_dados atuar nucleo inteligencia me...
# 201     analista_de_dados administrar banco dados   en...
# 202     analista_de_dados alocacao cliente   atuacao a...
# 203     analista_de_dados profissional tera principal ...
# 204     analista_de_dados suporte producao durante hor...
# 205     analista_de_dados analise resultados processam...
# 206     analista_de_dados identificar oportunidades ba...
# 207     analista_de_dados desenvolver etl   fazer inte...
# 208     analista_de_dados entender regras negocio empr...
# 209     analista_de_dados fazer acompanhamento estudos...
# 210     analista_de_dados experiencia participacao pro...
# 211     analista_de_dados atuara manutencao etl spark ...
# 212     analista_de_dados essence consultoria 14 anos ...
# 213     analista_de_dados medir   controlar   monitora...
# 214     analista_de_dados instrutor principal sera res...
# 215     analista_de_dados gerenciar backups fisicos nu...
# 216     analista_de_dados ira atuar infra estrutura pr...
# 217     analista_de_dados atuar desenvolvimento proces...
# 218     analista_de_dados sinqia focada criar implanta...
# 219     analista_de_dados ira elaborar consultas lingu...
# 220     analista_de_dados acompanhamento desenvolvimen...
# 221     analista_de_dados    estruturar objetos banco ...
# 222     analista_de_dados    apoiar organizacao implem...
# 223     analista_de_dados experiencia db schemas lingu...
# 224     analista_de_dados planejar executar administra...
# 225     analista_de_dados atuar atualizacao versao   a...
# 226     analista_de_dados realizar atendimento cliente...
# 227     analista_de_dados atuar administracao monitora...
# 228     analista_de_dados analise codigo sql otimizaca...
# 229     analista_de_dados atuar gestao ferramentas ges...
# 230     analista_de_dados experiencia governanca dados...
# 231     analista_de_dados analise desenvolvimento apli...
# 232     analista_de_dados atuar administracao banco da...
# 233     analista_de_dados atividades     atuar desenvo...
# 234     analista_de_dados sinqia focada criar implanta...
# 235     analista_de_dados suportar informacoes pertine...
# 236     analista_de_dados demonstrar capacidade conclu...
# 237     analista_de_dados responsavel identificar   de...
# 238     analista_de_dados foco administracao   dba   b...
# 239     analista_de_dados analise desenvolvimento proj...
# 240     analista_de_dados mapear riscos credito arranj...
# 241     analista_de_dados atuara analista banco dados ...
# 242     analista_de_dados fazendo parte dev python voc...
# 243     analista_de_dados entender identificar necessi...
# 244     analista_de_dados gestao manutencao maquinas v...
# 245     analista_de_dados instalacao   administracao m...
# 246     analista_de_dados gestao manutencao maquinas v...
# 247     analista_de_dados realizar manutencao instruco...
# 248     analista_de_dados atua linguagem programacao  ...
# 249     analista_de_dados atuar gerenciamento banco da...
# 250     analista_de_dados adora montar dashboards comp...
# 251     engenheiro_de_dados _ esperamos voce \r\r\n\r\...
# 252     engenheiro_de_dados _ trabalhar administracao ...
# 253     engenheiro_de_dados _ atuara analise dados qua...
# 254     engenheiro_de_dados _ atuar conhecimento lingu...
# 255     engenheiro_de_dados _ sera responsavel armazen...
# 256     engenheiro_de_dados _ responsavel gerenciament...
# 257     engenheiro_de_dados _ atuar cloudera hadoop   ...
# 258     engenheiro_de_dados _ atuar analytics projeto ...
# 259     engenheiro_de_dados _ criar pipelines escalave...
# 260     engenheiro_de_dados _ atuar ferramentas   spar...
# 261     engenheiro_de_dados _ criar pipelines dados lo...
# 262     engenheiro_de_dados _ coleta   combinacao disp...
# 263     engenheiro_de_dados _ tratamento   extracao an...
# 264     engenheiro_de_dados _ preparacao tratamentos d...
# 265     engenheiro_de_dados _ atuar scrum master squad...
# 266     engenheiro_de_dados _ atuara analise dados qua...
# 267     engenheiro_de_dados _ desenvolve softwares apl...
# 268     engenheiro_de_dados _ realizar ingestao dados ...
# 269     engenheiro_de_dados _ desenvolvimento orientad...
# 270     engenheiro_de_dados _ desenvolvimento avancado...
# 271     engenheiro_de_dados _ atuara modelagem   gesta...
# 272     engenheiro_de_dados _ cultura devops   fazer p...
# 273     engenheiro_de_dados _ participar ativamente pr...
# 274     engenheiro_de_dados _ trabalhar estrutura dado...
# 275     engenheiro_de_dados _ coleta   combinacao disp...
# 276     engenheiro_de_dados _ atuar capacidade analiti...
# 277     engenheiro_de_dados _ atuar preparacao tratame...
# 278     business_inteligence atuar   modelagem dw tunn...
# 1592    inteligencia_de_negocios acreditamos poder lib...
# 1593    inteligencia_de_negocios vaga sera conduzida e...
# 1594    inteligencia_de_negocios empresa zela coragem ...
# 1595    inteligencia_de_negocios oportunidades marketi...
# 1596    inteligencia_de_negocios venha fazer parte emp...
# 1597    inteligencia_de_negocios missao cargo atuar in...
# 1598    inteligencia_de_negocios segmento varejolocali...
# 1599    inteligencia_de_negocios limite inscricao 10 0...
# 1600    inteligencia_de_negocios necessario experienci...
# 1601    inteligencia_de_negocios venha fazer parte emp...
# 1602    inteligencia_de_negocios requisitos selecao su...
# 1603    inteligencia_de_negocios descricao atividadesg...
# 1604    inteligencia_de_negocios desenvolver equipe   ...
# 1605    inteligencia_de_negocios responsavel area econ...
# 1606    inteligencia_de_negocios n posicao   voce sera...
# 1607    inteligencia_de_negocios atividades responsabi...
# 1608    inteligencia_de_negocios definicao desenvolvim...
# 1609    data_science venha transformar educacao gente ...
# 1610    data_science coordenador science   voce tera o...
# 1611    cientista_de_dados cientista dados    desenvol...
# 1612    cientista_de_dados missao manter evoluir plata...
# 1613    cientista_de_dados cientista dados vertical in...
# 1614    cientista_de_dados buscamos profissional atuar...
# 1615    data_scientist procuramos talentos garra brilh...
# 1616    people_analytics desenvolvedor back end profis...
# 1617    people_analytics oportunidade estagiar area ge...
# 1618    data_analytics analytics specialist   reportin...
# 1619    data_analytics auditor pleno sistemas analytic...
# 1620    analista_de_dados contribuir evidencias   conh...
# 1621    analista_de_dados zenvia buscamos incessanteme...
# 1622    inteligencia_de_dados empresa ramo terceirizac...
# 1623    cientista_de_dados requisitos qualificacoes   ...
# 1624    cientista_de_dados requisitos qualificacoes gr...
# 1625    cientista_de_dados   university degree   maste...
# 1626    cientista_de_dados buscamos   pessoas assumam ...
# 1627    cientista_de_dados perfil desejado   formacao ...
# 1628    cientista_de_dados quais sao requisitos espera...
# 1629    cientista_de_dados requisitos mandatorios   in...
# 1630    cientista_de_dados requisitos qualificacoes   ...
# 1631    cientista_de_dados voce precisa   conhecer bem...
# 1632    cientista_de_dados requisitos obrigatorios   g...
# 1633    cientista_de_dados escolaridade   graduacao ci...
# 1634    cientista_de_dados pre requisitos   graduacao ...
# 1635    cientista_de_dados requisitos necessarios   co...
# 1636    cientista_de_dados requerido   python   sql se...
# 1637    cientista_de_dados habilidades obrigatorias   ...
# 1638    cientista_de_dados habilidades obrigatorias   ...
# 1639    cientista_de_dados vaga cliente geekhunter   c...
# 1640    cientista_de_dados habilidades requisitos exig...
# 1641    cientista_de_dados habilidades sao esperadas v...
# 1642    cientista_de_dados requisitos   dominio lingua...
# 1643    cientista_de_dados cientista dados hotmart   b...
# 1644    cientista_de_dados buscamos   solida formacao ...
# 1645    cientista_de_dados quais serao desafios contri...
# 1646    cientista_de_dados exigencias vaga   afinidade...
# 1647    cientista_de_dados requisitos   conhecimento e...
# 1648    cientista_de_dados requisitos   experiencia ma...
# 1649    cientista_de_dados habilidades tecnicas   mest...
# 1650    cientista_de_dados requisitos   superior compl...
# 1651    cientista_de_dados fazer parte super   precisa...
# 1652    cientista_de_dados necessario vaga   formacao ...
# 1653    cientista_de_dados requisitos   graduacao curs...
# 1654    cientista_de_dados requisitos cargo   habilida...
# 1655    cientista_de_dados matematica   algebra linear...
# 1656    cientista_de_dados requisitos qualificacoes   ...
# 1657    cientista_de_dados requisitos imprescindiveis ...
# 1658    cientista_de_dados curso superior completo est...
# 1659    cientista_de_dados oportunidade   precisamos v...
# 1660    cientista_de_dados sinqia focada criar implant...
# 1661    cientista_de_dados voce traz   experiencia sof...
# 1662    cientista_de_dados necessario conhecimento lin...
# 1663    cientista_de_dados atividades vaga   coleta da...
# 1664    cientista_de_dados buscamos   procuramos pesso...
# 1665    cientista_de_dados perfil candidato   busca pe...
# 1666    cientista_de_dados coordene equipe science ger...
# 1667    cientista_de_dados conhecimentos   conheciment...
# 1668    cientista_de_dados skills   1   hard skills   ...
# 1669    cientista_de_dados skills   solido conheciment...
# 1670    paulo_pedro \n\n fone    55 11   97109 2031 \n...
# 1671    paulo_pedro \n\n fone    55 11   97109 2031 \n...
# 1672    paulo_pedro \n\n fone    55 11   97109 2031 \n...
# 1673    paulo_pedro \n\n fone    55 11   97109 2031 \n...
# 1674    paulo_pedro \n\n fone    55 11   97109 2031 \n...
# Name: clean, dtype: object

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
sent
# Out:
# [['cientista_de_dados',
#   'cientista',
#   'dados',
#   'considerado',
#   'nova',
#   'geracao',
#   'especialistas',
#   'analise',
#   'dados',
#   'habilidades',
#   'tecnicas',
#   'resolver',
#   'problemas',
#   'complexos',
#   'curiosidade',
#   'explorar',
#   'quais',
#   'problemas',
#   'necessitam',
#   'solucao',
#   'conhecimentos',
#   'especificos',
#   'linguagens',
#   'programacao',
#   'analise',
#   'dados',
#   'r',
#   'python',
#   'sql',
#   'visualizacao',
#   'dados',
#   'spotfire',
#   'powerbi',
#   'cognos',
#   'mining',
#   'analise',
#   'exploratoria',
#   'dados',
#   'infraestrutura',
#   'big',
#   'hadoop',
#   'mapreduce',
#   'spark',
#   'algoritmos',
#   'regressao',
#   'logistica',
#   'arvore',
#   'decisao',
#   'random',
#   'forest',
#   'xgbooster',
#   'regressao',
#   'linear',
#   'notebook',
#   'jupyter',
#   'zepellin',
#   'hive',
#   'hbase',
#   'etl',
#   'datastage',
#   'sqoop',
#   'experiencia',
#   'projetos',
#   'analytics',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'analise',
#   'sentimentos',
#   'analise',
#   'conteudo',
#   'nlp',
#   'word2vec',
#   'bag',
#   'words',
#   'git',
#   'gitlab',
#   'hortonworks',
#   'cloudera',
#   'habilidades',
#   'comunicacao',
#   'estatisticas',
#   'foco',
#   'solucao',
#   'problemas',
#   'graduacao',
#   'area',
#   'ti',
#   'qualquer',
#   'outra',
#   'area',
#   'acompanhada',
#   'pos',
#   'graduacao',
#   'area',
#   'ti'],
#  ['cientista_de_dados',
#   'utilizar',
#   'modelos',
#   'matematicos',
#   'estatisticos',
#   'preditivos',
#   'correlacao',
#   'segmentacao',
#   'machine',
#   'learning',
#   'construir',
#   'solucoes',
#   'apoio',
#   'decisao',
#   'negocio',
#   'clientes',
#   'analisar',
#   'identificar',
#   'tendencias',
#   'comportamentos',
#   'uso',
#   'ferramentas',
#   'estatisticas',
#   'bi',
#   'analytics',
#   'acompanhar',
#   'desempenho',
#   'modelos',
#   'producao',
#   'sempre',
#   'cumprindo',
#   'funcao',
#   'alta',
#   'interacao',
#   'diversas',
#   'areas',
#   'empresa',
#   'marketing',
#   'inovacao',
#   'entender',
#   'oportunidades',
#   'propor',
#   'melhorias',
#   'desejavel',
#   'ciencias',
#   'computacao',
#   'estatistica',
#   'engenharias',
#   'areas',
#   'correlatas'],
#  ['cientista_de_dados',
#   'interpretacao',
#   'tendencias',
#   'refino',
#   'base',
#   'dados',
#   'testes',
#   'hipoteses',
#   'modelos',
#   'estruturar',
#   'dar',
#   'manutencao',
#   'sistemas',
#   'informacao',
#   'desenvolver',
#   'capacidade',
#   'analitica',
#   'empresa',
#   'aprimorar',
#   'processos',
#   'dados',
#   'meio',
#   'melhoria',
#   'continua',
#   'graduacao',
#   'cursando',
#   'engenharia',
#   'fisica',
#   'matematica',
#   'matematica',
#   'aplicada',
#   'estatistica',
#   'economia',
#   'areas',
#   'correlatas',
#   'diferencial',
#   'gostar',
#   'analise',
#   'pensamento',
#   'logico',
#   'apurado',
#   'facilidade',
#   'matematica',
#   'estatistica',
#   'conhecer',
#   'alguma',
#   'linguagem',
#   'programacao',
#   'r',
#   'python',
#   'julia',
#   'nosql',
#   'spark',
#   'hadoop',
#   'consulta',
#   'sql'],
#  ['cientista_de_dados',
#   'modelar',
#   'problemas',
#   'complexos',
#   'identificar',
#   'oportunidades',
#   'dados',
#   'gerar',
#   'insights',
#   'meio',
#   'tecnicas',
#   'diversas',
#   'refino',
#   'base',
#   'dados',
#   'selecionar',
#   'melhor',
#   'tecnica',
#   'science',
#   'utilizada',
#   'cada',
#   'analise',
#   'testes',
#   'hipoteses',
#   'modelos',
#   'estruturar',
#   'dar',
#   'manutencao',
#   'sistemas',
#   'informacao',
#   'desenvolver',
#   'capacidade',
#   'analitica',
#   'empresa',
#   'aprimorar',
#   'processos',
#   'dados',
#   'meio',
#   'melhoria',
#   'continua',
#   'gerenciar',
#   'projetos',
#   'garantindo',
#   'analise',
#   'riscos',
#   'graduacao',
#   'engenharia',
#   'arquitetura',
#   'dados',
#   'fisica',
#   'matematica',
#   'matematica',
#   'aplicada',
#   'estatistica',
#   'economia',
#   'areas',
#   'correlatas',
#   'diferencial',
#   'gostar',
#   'analise',
#   'pensamento',
#   'logico',
#   'apurado',
#   'facilidade',
#   'matematica',
#   'estatistica',
#   'conhecer',
#   'alguma',
#   'linguagem',
#   'programacao',
#   'r',
#   'python',
#   'julia',
#   'nosql',
#   'spark',
#   'hadoop',
#   'consulta',
#   'sql',
#   'conhecimento',
#   'ia',
#   'inteligencia',
#   'artificial',
#   'conhecimento',
#   'jurimetria',
#   'comportamento',
#   'usuario'],
#  ['cientista_de_dados',
#   'realizar',
#   'projetos',
#   'sprint',
#   'desenvolvimento',
#   'implantacao',
#   'solucoes',
#   'automatizacao',
#   'desenvolvimento',
#   'implantacao',
#   'solucoes',
#   'automatizacao',
#   'utilizando',
#   'scripts',
#   'vba',
#   'sap',
#   'script',
#   'outras',
#   'ferramentas',
#   'rpa',
#   'cada',
#   'projeto',
#   'sprint',
#   'engloba',
#   'seguintes',
#   'etapas',
#   'pre',
#   'sprint',
#   'entendimento',
#   'objetivo',
#   'demanda',
#   'levantamento',
#   'requisitos',
#   'sprint',
#   'mapeamento',
#   'stakeholders',
#   'projeto',
#   'recursos',
#   'necessarios',
#   'desenvolvimento',
#   'sprint',
#   'participar',
#   'contribuir',
#   'workshop',
#   'eventos',
#   'design',
#   'thinking',
#   'estruturacao',
#   'escopo',
#   'objetivo',
#   'projeto',
#   'aplicavel',
#   'realizacao',
#   'entrevistas',
#   'pessoas',
#   'chave',
#   'aprofundamento',
#   'entendimento',
#   'mapeamento',
#   'riscos',
#   'restricoes',
#   'proposicao',
#   'alternativas',
#   'realizacao',
#   'mapeamento',
#   'processo',
#   'procedimentos',
#   'serem',
#   'automatizados',
#   'desenho',
#   'comparativo',
#   'processo',
#   'atual',
#   'processo',
#   'proposto',
#   'organizacao',
#   'etapas',
#   'sprint',
#   'delimitacao',
#   'escopo',
#   'prototipacao',
#   'desenho',
#   'produto',
#   'sprint',
#   'conjunto',
#   'equipe',
#   'mapeada',
#   'po',
#   'product',
#   'owner',
#   'mapeamento',
#   'todas',
#   'bases',
#   'dados',
#   'necessarias',
#   'execucao',
#   'sprint',
#   'levantamento',
#   'direto',
#   'via',
#   'queries',
#   'bancos',
#   'dados',
#   'existentes',
#   'via',
#   'articulacao',
#   'outras',
#   'areas',
#   'apoio',
#   'aplicavel',
#   'sprint',
#   'tratamento',
#   'limpeza',
#   'dados',
#   'levantados',
#   'aplicavel',
#   'desenvolvimento',
#   'implantacao',
#   'solucao',
#   'automatizacao',
#   'levantamento',
#   'novos',
#   'dados',
#   'outros',
#   'recursos',
#   'identificados',
#   'necessarios',
#   'durante',
#   'sprint',
#   'envolvimento',
#   'pessoas',
#   'chave',
#   'articulacao',
#   'areas',
#   'apoio',
#   'validacao',
#   'intermediaria',
#   'po',
#   'product',
#   'owner',
#   'outros',
#   'stakeholders',
#   'pos',
#   'sprint',
#   'preparacao',
#   'apresentacao',
#   'powerpoint',
#   'evidenciando',
#   'principais',
#   'ganhos',
#   'impactos',
#   'trazidos',
#   'projeto',
#   'visao',
#   'antes',
#   'x',
#   'realizacao',
#   'piloto',
#   'aplicacao',
#   'scripts',
#   'desenvolvidos',
#   'apresentacao',
#   'validacao',
#   'produto',
#   'final',
#   'junto',
#   'po',
#   'product',
#   'owner',
#   'outros',
#   'stakeholders',
#   'mapeados',
#   'realizacao',
#   'ajustes',
#   'melhorias',
#   'solicitadas',
#   'documentacao',
#   'todos',
#   'criterios',
#   'considerados',
#   'premissas',
#   'assumidas',
#   'guia',
#   'usuario',
#   'manutencao',
#   'operacionalizacao',
#   'produto',
#   'definicao',
#   'numero',
#   'sprints',
#   'necessarios',
#   'conclusao',
#   'demanda',
#   'sera',
#   'estimado',
#   'tabela',
#   'complexidade',
#   'demandas',
#   'x',
#   'sprints',
#   'projetos',
#   'sprint',
#   'terao',
#   'participacao',
#   'contribuicao',
#   'profissionais',
#   'petrobras',
#   'conhecimento',
#   'problema',
#   'processo',
#   'abordado',
#   'etapa',
#   'sprint',
#   'deve',
#   'iniciada',
#   'apos',
#   'finalizados',
#   'todos',
#   'procedimentos',
#   'previstos',
#   'etapa',
#   'pre',
#   'sprint',
#   'visando',
#   'garantir',
#   'todos',
#   'recursos',
#   'infraestrutura',
#   'informacoes',
#   'necessarias',
#   'bom',
#   'andamento',
#   'eficacia',
#   'sprint',
#   'prazo',
#   'estimado',
#   'semana',
#   '5',
#   'dias',
#   'uteis',
#   'refere',
#   'etapa',
#   'sprint',
#   'etapas',
#   'pre',
#   'sprint',
#   'pos',
#   'sprint',
#   'podem',
#   'variar',
#   'acordo',
#   'projetos',
#   'item',
#   'estimativa',
#   'esforco',
#   'realzacao',
#   'sao',
#   'apresentadas',
#   'estimativas',
#   'esforco',
#   'dedicacao',
#   'realizacao',
#   'todas',
#   'etapas',
#   'pre',
#   'sprint',
#   'sprint',
#   'pos',
#   'sprint',
#   'poderao',
#   'ocorrer',
#   'demandas',
#   'projetos',
#   'sprints',
#   'concomitantes',
#   'sprint',
#   'tempo',
#   'solucoes',
#   'podem',
#   'envolver',
#   'configuracao',
#   'consumo',
#   'escrita',
#   'i',
#   'api',
#   'webservice',
#   'barramento',
#   'servicos',
#   'odata',
#   'oportunidade',
#   'estendida',
#   'todas',
#   'pessoas',
#   'deficiencia'],
#  ['cientista_de_dados',
#   'desenvolvimento',
#   'ajudar',
#   'construcao',
#   'analises',
#   'ferramentas',
#   'apoio',
#   'tomada',
#   'decisao',
#   'criacao',
#   'indicadores',
#   'controle',
#   'qualidade',
#   'kpi',
#   'participar',
#   'migracao',
#   'ambiente',
#   'nuvem'],
#  ['cientista_de_dados',
#   'sprints',
#   'adicionais',
#   'avulsos',
#   'analytics',
#   'machine',
#   'learning',
#   'simulacoes',
#   'realizacao',
#   'sprints',
#   'adicionais',
#   'analytics',
#   'machine',
#   'learning',
#   'simulacoes',
#   'complemento',
#   'servico',
#   '4',
#   '1',
#   'necessario',
#   'conforme',
#   'estimativas',
#   'apresentadas',
#   'tabela',
#   'complexidade',
#   'demandas',
#   'x',
#   'sprints',
#   'realizacao',
#   'sprints',
#   'avulsos',
#   'implementacao',
#   'melhorias',
#   'desenvolvimento',
#   'trabalhos',
#   'analytics',
#   'machine',
#   'learning',
#   'simulacoes',
#   'sprint',
#   'tratamento',
#   'limpeza',
#   'dados',
#   'levantados',
#   'desenvolvimento',
#   'projeto',
#   'analytics',
#   'machine',
#   'learning',
#   'simulacao',
#   'conforme',
#   'objetivo',
#   'produto',
#   'definido',
#   'levantamento',
#   'novos',
#   'dados',
#   'outros',
#   'recursos',
#   'identificados',
#   'necessarios',
#   'durante',
#   'sprint',
#   'envolvimento',
#   'pessoas',
#   'chave',
#   'articulacao',
#   'areas',
#   'apoio',
#   'validacao',
#   'intermediaria',
#   'po',
#   'product',
#   'owner',
#   'outros',
#   'stakeholders',
#   'conhecimento',
#   'modelos',
#   'banco',
#   'dados',
#   'multidimensionais',
#   'conhecimento',
#   'selecao',
#   'captura',
#   'preparacao',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'conhecimento',
#   'mineracao',
#   'dados',
#   'modelagem',
#   'estatistica',
#   'conhecimento',
#   'tecnicas',
#   'avancadas',
#   'apresentacao',
#   'visualizacao',
#   'dados',
#   'experiencia',
#   'ferramenta',
#   'apresentacao',
#   'powerpoint',
#   'experiencia',
#   'ferramentas',
#   'bi',
#   'ex',
#   'spotfire',
#   'power',
#   'bi',
#   'experiencia',
#   'linguagens',
#   'science',
#   'python',
#   'r',
#   'experiencia',
#   'ferramentas',
#   'preparacao',
#   'dados',
#   'mineracao',
#   'dados',
#   'aprendizagem',
#   'maquina',
#   'knime',
#   'miner'],
#  ['cientista_de_dados',
#   'modelar',
#   'problemas',
#   'complexos',
#   'identificar',
#   'oportunidades',
#   'dados',
#   'gerar',
#   'insights',
#   'meio',
#   'tecnicas',
#   'estatisticas',
#   'algoritmos',
#   'ferramentas',
#   'visualizacao',
#   'alem',
#   'profissional',
#   'devera',
#   'integrar',
#   'qualificar',
#   'dados',
#   'diferentes',
#   'origens',
#   'grande',
#   'volume',
#   'arquitetando',
#   'estruturas',
#   'dados',
#   'ambientes',
#   'computacionais',
#   'graduacao',
#   'engenharia',
#   'ciencia',
#   'computacao',
#   'matematica',
#   'estatistica',
#   'areas',
#   'relacionadas',
#   'experiencia',
#   'uso',
#   'ferramentas',
#   'pacotes',
#   'estatisticos',
#   'experiencia',
#   'uso',
#   'banco',
#   'dados',
#   'conhecimento',
#   'industrias',
#   'areas',
#   'negocio'],
#  ['cientista_de_dados',
#   'empresa',
#   'referencia',
#   'driven',
#   'marketing',
#   'cro',
#   'crm',
#   'servicos',
#   'tecnologias',
#   'focados',
#   'melhores',
#   'resultados',
#   'contrata',
#   'programador',
#   'sql',
#   'porto',
#   'alegre',
#   'rs',
#   'busca',
#   'pessoas',
#   'apaixonadas',
#   'dados',
#   'capazes',
#   'extrair',
#   'insights',
#   'informacoes',
#   'relevantes',
#   'partir',
#   'gigantescos',
#   'volumes',
#   'dados',
#   'voce',
#   'ira',
#   'trabalhar',
#   'maiores',
#   'clientes',
#   'varejo',
#   'america',
#   'latina',
#   'tendo',
#   'impacto',
#   'vida',
#   'milhoes',
#   'pessoas',
#   'responsabilidades',
#   'estao',
#   'atuar',
#   'colaboracao',
#   'analistas',
#   'dados',
#   'criacao',
#   'aplicacao',
#   'algoritmos',
#   'modelos',
#   'estatisticos',
#   'desenvolver',
#   'sustentar',
#   'workflows',
#   'dados',
#   'atendam',
#   'necessidades',
#   'negocio',
#   'empregar',
#   'algoritmos',
#   'modelos',
#   'estatisticos',
#   'previsao',
#   'receita',
#   'analise',
#   'churne',
#   'identificar',
#   'grupos',
#   'consumidores',
#   'afinidade',
#   'outros',
#   'modelar',
#   'manipular',
#   'bancos',
#   'dados',
#   'skills',
#   'solido',
#   'conhecimento',
#   'estatistica',
#   'conhecimentos',
#   'programacao',
#   'r',
#   'python',
#   'java',
#   'experiencia',
#   'desenvolvimento',
#   'aplicacao',
#   'algoritmos',
#   'classificacao',
#   'agrupamento',
#   'predicao',
#   'bancos',
#   'dados',
#   'relacionais',
#   'mysql',
#   'postgresql',
#   'oracle',
#   'ms',
#   'sql',
#   'server',
#   'ingles',
#   'intermediario',
#   'experiencia',
#   'pytorch',
#   'tensorflow',
#   'diferenciais',
#   'formacao',
#   'ciencias',
#   'exatas',
#   'estatistica',
#   'matematica',
#   'engenharias',
#   'afins',
#   'nocoes',
#   'bancos',
#   'dados',
#   'nao',
#   'relacionais',
#   'experiencia',
#   'grandes',
#   'volumes',
#   'dados',
#   'big'],
#  ['cientista_de_dados',
#   'sera',
#   'responsabilidade',
#   'levantamento',
#   'analise',
#   'compilacao',
#   'informacoes',
#   'sobre',
#   'dados',
#   'projetos',
#   'empresa',
#   'fornecendo',
#   'relatorios',
#   'modelos',
#   'previsao',
#   'sugestao',
#   'fundamentar',
#   'possibilitar',
#   'tomada',
#   'decisoes',
#   'dentro',
#   'projetos',
#   'formacao',
#   'superior',
#   'engenharias',
#   'matematica',
#   'estatistica',
#   'computacao',
#   'areas',
#   'correlatas',
#   'experiencia',
#   'compativel',
#   'comprovada',
#   'habilidade',
#   'comunicacao',
#   'estatistica',
#   'inteligencia',
#   'artificial',
#   'python',
#   'r',
#   'etl',
#   'scikit',
#   'learn',
#   'pandas',
#   'aprendizado',
#   'supervisionado',
#   'nao',
#   'supervisionado',
#   'redes',
#   'neurais',
#   'ingles',
#   'avancado',
#   'leitura',
#   'fluente',
#   'diferencial',
#   'experiencia',
#   'visao',
#   'computacional',
#   'classica',
#   'deep',
#   'learning'],
#  ['cientista_de_dados',
#   'curso',
#   'superior',
#   'completo',
#   'estatistica',
#   'economia',
#   'tecnologia',
#   'informacao',
#   'engenharia',
#   'matematica',
#   'areas',
#   'afins',
#   'python',
#   'r',
#   'sql',
#   'avancados',
#   'estatistica',
#   'big',
#   'bi',
#   'machine',
#   'learning',
#   'ia',
#   'conhecimento',
#   'contabil',
#   'sistema',
#   'financeiro',
#   'desejavel',
#   'experiencia',
#   'area'],
#  ['cientista_de_dados',
#   'programacao',
#   'preferencia',
#   'python',
#   'r',
#   'trabalhar',
#   'plataformas',
#   'nuvem',
#   'azure',
#   'aws',
#   'profundo',
#   'entendimento',
#   'tecnicas',
#   'modernas',
#   'machine',
#   'learning',
#   'algoritmos',
#   'funcionam',
#   'nao',
#   'apenas',
#   'los',
#   'experiencia',
#   'profissional',
#   'academica',
#   'pessoal',
#   'projetos',
#   'ciencia',
#   'dados',
#   'conhecimentos',
#   'tecnicas',
#   'visualizacao',
#   'tableau',
#   'power',
#   'bi',
#   'conhecimentos',
#   'conceitos',
#   'big',
#   'hadoop',
#   'spark',
#   'hive',
#   'hbase',
#   'conhecimentos',
#   'deep',
#   'learning',
#   'implementacao',
#   'tensorflow',
#   'keras',
#   'graduacao',
#   'engenharia',
#   'ciencia',
#   'computacao',
#   'estatistica',
#   'economia',
#   'matematica',
#   'fisica',
#   'correlatas'],
#  ['cientista_de_dados',
#   'organizar',
#   'validar',
#   'dados',
#   'gerados',
#   'areas',
#   'negocio',
#   'manipular',
#   'grandes',
#   'quantidades',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'transforma',
#   'los',
#   'informacoes',
#   'relevantes',
#   'gestores',
#   'interessados',
#   'possam',
#   'tomar',
#   'decisoes',
#   'eficientes',
#   'aplicar',
#   'variacoes',
#   'linguagens',
#   'programacao',
#   'python',
#   'r',
#   'dentre',
#   'outras',
#   'resolucao',
#   'problemas',
#   'buscar',
#   'padroes',
#   'procurar',
#   'ordem',
#   'padroes',
#   'dados',
#   'identificar',
#   'tendencias',
#   'elaborar',
#   'dashboards',
#   'foco',
#   'processos',
#   'especificos',
#   'aplicacao',
#   'regras',
#   'negocio',
#   'garantir',
#   'qualidade',
#   'dados',
#   'seguranca',
#   'informacao',
#   'performance',
#   'dashboards',
#   'disponiveis',
#   'prover',
#   'informacoes',
#   'claras',
#   'consistentes',
#   'negocio',
#   'sobre',
#   'processo',
#   'transformar',
#   'dados',
#   'brutos',
#   'insights',
#   'discutir',
#   'areas',
#   'backoffice',
#   'negocios',
#   'insights',
#   'estrategicos',
#   'sobre',
#   'evolucao',
#   'informacoes',
#   'apresentadas',
#   'dashboards',
#   'construir',
#   'avaliar',
#   'validar',
#   'modelos',
#   'preditivos',
#   'prescritivos',
#   'analises',
#   'dados',
#   'propor',
#   'melhorias',
#   'processos',
#   'experiencia',
#   'manuseio',
#   'grandes',
#   'quantidades',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'transforma',
#   'los',
#   'informacoes',
#   'relevantes',
#   'gestores',
#   'interessados',
#   'possam',
#   'tomar',
#   'decisoes',
#   'eficientes',
#   'conhecimentos',
#   'linguagens',
#   'programacao',
#   'python',
#   'r',
#   'dentre',
#   'outras',
#   'resolucao',
#   'problemas',
#   'buscar',
#   'padroes',
#   'conhecimento',
#   'dashboards',
#   'foco',
#   'processos',
#   'especificos',
#   'aplicacao',
#   'regras',
#   'negocio',
#   'conhecimentos',
#   'solidos',
#   'linguagens',
#   'manipulacao',
#   'dados',
#   'sql',
#   'python',
#   'r',
#   'dentre',
#   'outras',
#   'estatistica',
#   'fundamentos',
#   'machine',
#   'learning',
#   'plataforma',
#   'hadoop',
#   'conhecimentos',
#   'ferramentas',
#   'bi',
#   'preferencialmente',
#   'tableau',
#   'conhecimentos',
#   'alteryx',
#   'metodologias',
#   'ageis',
#   'kanban',
#   'scrum',
#   'desenho',
#   'processos',
#   'negocio',
#   'conhecimentos',
#   'deep',
#   'learning',
#   'logica',
#   'fuzzy',
#   'formacao',
#   'superior',
#   'engenharia',
#   'estatistica',
#   'matematica',
#   'ciencia',
#   'computacao',
#   'cursos',
#   'afins'],
#  ['cientista_de_dados',
#   'adquirir',
#   'avaliar',
#   'processar',
#   'dados',
#   'varias',
#   'fontes',
#   'sistemas',
#   'plataformas',
#   'big',
#   'gerenciar',
#   'dados',
#   'end',
#   'end',
#   'determinar',
#   'abordagem',
#   'estrategica',
#   'gerenciamento',
#   'dados',
#   'manipulacao',
#   'transformacao',
#   'dados',
#   'meio',
#   'etls',
#   'pipelines',
#   'streamings',
#   'realtime',
#   'nao',
#   'suportar',
#   'correcao',
#   'bugs',
#   'analises',
#   'desempenho',
#   'longo',
#   'pipeline',
#   'dados',
#   'colaborar',
#   'cientistas',
#   'dados',
#   'mapear',
#   'campos',
#   'dados',
#   'hipoteses',
#   'organizar',
#   'preparar',
#   'dados',
#   'uso',
#   'modelos',
#   'analiticos',
#   'avancados',
#   'desenvolvimento',
#   'usando',
#   'java',
#   'python',
#   'controle',
#   'versao',
#   'git',
#   'gerenciamento',
#   'dependencias',
#   'usando',
#   'maven',
#   'pip',
#   'fluxos',
#   'trabalho',
#   'equipe',
#   'usando',
#   'branches',
#   'pull',
#   'requests',
#   'dominio',
#   'linguagens',
#   'programacao',
#   'java',
#   'python',
#   'desejavel',
#   'r',
#   'vivencia',
#   'sistemas',
#   'distribuidos',
#   'incluindo',
#   'conceitos',
#   'clusters',
#   'sharding',
#   'quorum',
#   'conhecimento',
#   'arquitetura',
#   'hadoop',
#   'experiencia',
#   'ecossistema',
#   'hadoop',
#   'hive',
#   'spark',
#   'experiencia',
#   'jupiter',
#   'notebooks',
#   'afins',
#   'solidos',
#   'conhecimentos',
#   'machine',
#   'learning',
#   'deep',
#   'learning'],
#  ['cientista_de_dados',
#   'transformar',
#   'fontes',
#   'dados',
#   'informacoes',
#   'relatorios',
#   'acessiveis',
#   'facilitando',
#   'tomada',
#   'decisao',
#   'gestores',
#   'empresa',
#   'transformar',
#   'fontes',
#   'dados',
#   'informacoes',
#   'relatorios',
#   'acessiveis',
#   'facilitando',
#   'tomada',
#   'decisao',
#   'gestores',
#   'empresa'],
#  ['cientista_de_dados',
#   'solucionar',
#   'problemas',
#   'negocios',
#   'tecnicas',
#   'orientacao',
#   'dados',
#   'trabalhar',
#   'variedade',
#   'linguagens',
#   'programacao',
#   'procurar',
#   'ordens',
#   'padroes',
#   'dados',
#   'bem',
#   'detectar',
#   'tendencias',
#   'podem',
#   'ajudar',
#   'resultados',
#   'empresa',
#   'atuar',
#   'definicao',
#   'solucao',
#   'entendimento',
#   'processos',
#   'negocio',
#   'usar',
#   'tecnicas',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'text',
#   'analytics',
#   'criar',
#   'solucoes',
#   'novas',
#   'escalaveis',
#   'experiencia',
#   'tecnicas',
#   'apresentacao',
#   'visualizacao',
#   'dados',
#   'graduacao',
#   'completa',
#   'ti',
#   'matematica',
#   'experiencia',
#   'manipulacao',
#   'dados',
#   'ambiente',
#   'big',
#   'experiencia',
#   'hadoop',
#   'streaming',
#   'dados',
#   'spark',
#   'dominio',
#   'motores',
#   'nlp',
#   'text',
#   'minning',
#   'clusterizacao',
#   'conhecimento',
#   'menos',
#   'dois',
#   'banco',
#   'dados'],
#  ['cientista_de_dados',
#   'ira',
#   'atuar',
#   'ambientes',
#   'alta',
#   'criticidade',
#   'metricas',
#   'acompanhamento',
#   'desenvolvimento',
#   'experiencia',
#   'ramo',
#   'automotivo',
#   'componentes',
#   'eletronicos',
#   'formacao',
#   'matematica',
#   'estatistica',
#   'tecnologia',
#   'informacao',
#   'desejavel',
#   'certificacoes',
#   'itil',
#   'scrum',
#   'metodologias',
#   'ferramenta',
#   'siebel',
#   'crm'],
#  ['cientista_de_dados',
#   'fazer',
#   'parte',
#   'super',
#   'precisamos',
#   'voce',
#   'salve',
#   'desenvolvimento',
#   'modelos',
#   'machine',
#   'learning',
#   'ml',
#   'utilizando',
#   'tecnicas',
#   'regressao',
#   'classificacao',
#   'redes',
#   'neurais',
#   'deep',
#   'learning',
#   'realizacao',
#   'pesquisas',
#   'diversas',
#   'fontes',
#   'dados',
#   'redes',
#   'sociais',
#   'geolocalizacao',
#   'microdados',
#   'scraping',
#   'outros',
#   'implementar',
#   'validar',
#   'modelos',
#   'preditivos',
#   'criar',
#   'modelos',
#   'estatisticos',
#   'foco',
#   'big',
#   'compreender',
#   'trabalhar',
#   'processo',
#   'etl',
#   'experiencia',
#   'programacao',
#   'python',
#   'r',
#   'matlab',
#   'conhecimento',
#   'banco',
#   'dados',
#   'sql',
#   'postgresql',
#   'mysql',
#   'nosql',
#   'mongodb',
#   'couchdb',
#   'analisar',
#   'identificar',
#   'tendencias',
#   'comportamentos',
#   'uso',
#   'estatistica',
#   'acompanhar',
#   'desempenho',
#   'modelos',
#   'machine',
#   'learning',
#   'producao',
#   'cuidando',
#   'sempre',
#   'cumprindo',
#   'objetivos',
#   'empresa',
#   'desenvolver',
#   'modelos',
#   'matematicos',
#   'atendam',
#   'necessidades',
#   'areas',
#   'negocios',
#   'acordo',
#   'problema',
#   'especifico',
#   'solucionado',
#   'desenvolver',
#   'mecanismos',
#   'controle',
#   'qualidade',
#   'assegure',
#   'assertividade',
#   'resultado',
#   'modelos',
#   'capacidade',
#   'comunicar',
#   'resultados',
#   'eficiencia',
#   'areas',
#   'negocio',
#   'mindlaber',
#   'apaixonado',
#   'educacao',
#   'muita',
#   'vontade',
#   'gerar',
#   'impacto',
#   'positivo',
#   'pessoas',
#   'criancas',
#   'sociedade',
#   'vontade',
#   'aprender',
#   'grandes',
#   'desafios',
#   'inovar',
#   'junto',
#   'jovem',
#   'mega',
#   'mao',
#   'massa',
#   'resiliente',
#   'suficiente',
#   'encarar',
#   'diversos',
#   'desafios',
#   'rotina',
#   'dinamica',
#   'aprendizagem',
#   'rapido',
#   'crescimento',
#   'podem',
#   'trazer',
#   'enxergar',
#   'usuario',
#   'razao',
#   'acordar',
#   'todos',
#   'dias',
#   'manha',
#   'vestir',
#   'camisa',
#   'empresa',
#   'transformar',
#   'milhares',
#   'linhas',
#   'codigo',
#   'potente',
#   'ferramenta',
#   'transformacao',
#   'social',
#   'educacional',
#   'experiencias',
#   'mind',
#   'lab',
#   'evolucao',
#   'diaria',
#   'ambiente',
#   'horizontal',
#   'aberto',
#   'dinamico',
#   'alto',
#   'impacto',
#   'social',
#   'aprendizado',
#   'vida',
#   'venha',
#   'mindlaber'],
#  ['cientista_de_dados',
#   'considerado',
#   'nova',
#   'geracao',
#   'especialistas',
#   'analise',
#   'dados',
#   'habilidades',
#   'tecnicas',
#   'resolver',
#   'problemas',
#   'complexos',
#   'curiosidade',
#   'explorar',
#   'quais',
#   'problemas',
#   'necessitam',
#   'solucao',
#   'cientistas',
#   'dados',
#   'sao',
#   'parte',
#   'matematicos',
#   'cientistas',
#   'computacao',
#   'investigadores',
#   'tendencias',
#   'experiencia',
#   'conhecimento',
#   'funcao',
#   'ensino',
#   'superior',
#   'completo'],
#  ['cientista_de_dados',
#   'projetar',
#   'implementar',
#   'suportar',
#   'plataforma',
#   'fornece',
#   'acesso',
#   'seguro',
#   'grandes',
#   'conjuntos',
#   'dados',
#   'interface',
#   'clientes',
#   'area',
#   'comercial',
#   'estrategica',
#   'companhia',
#   'reunindo',
#   'requisitos',
#   'entregando',
#   'solucoes',
#   'completas',
#   'bi',
#   'modele',
#   'dados',
#   'metadados',
#   'suportar',
#   'relatorios',
#   'ad',
#   'hoc',
#   'pre',
#   'construidos',
#   'desenvolvimento',
#   'manter',
#   'relatorios',
#   'metricas',
#   'paineis',
#   'controle',
#   'continuos',
#   'impulsionar',
#   'principais',
#   'decisoes',
#   'negocios',
#   'reconhecer',
#   'adotar',
#   'melhores',
#   'praticas',
#   'relatorios',
#   'analises',
#   'integridade',
#   'dados',
#   'projeto',
#   'teste',
#   'analise',
#   'validacao',
#   'documentacao',
#   'ajustar',
#   'desempenho',
#   'aplicativos',
#   'consultas',
#   'usando',
#   'ferramentas',
#   'criacao',
#   'perfil',
#   'sql',
#   'analisar',
#   'resolver',
#   'problemas',
#   'raiz',
#   'recuando',
#   'entender',
#   'contexto',
#   'amplo',
#   'aprender',
#   'compreender',
#   'ampla',
#   'gama',
#   'fonte',
#   'dados',
#   'sabendo',
#   'quais',
#   'usar',
#   'manter',
#   'atualizado',
#   'avancos',
#   'tecnologias',
#   'big',
#   'execute',
#   'pilotos',
#   'projetar',
#   'arquitetura',
#   'dados',
#   'escalar',
#   'aumento',
#   'volume',
#   'dados',
#   'melhorar',
#   'continuamente',
#   'processos',
#   'extracao',
#   'relatorio',
#   'analise',
#   'automatizando',
#   'simplificando',
#   'suporte',
#   'autoatendimento',
#   'conjuntos',
#   'dados',
#   'bacharel',
#   'ciencia',
#   'computacao',
#   'campo',
#   'tecnico',
#   'relacionado',
#   'experiencia',
#   'coleta',
#   'requisitos',
#   'formulacao',
#   'metricas',
#   'negocios',
#   'relatorios',
#   'excelente',
#   'conhecimento',
#   'ms',
#   'sql',
#   'server',
#   'variacoes',
#   'ssis',
#   'experiencia',
#   'etl',
#   'bancos',
#   'dados',
#   'ambiente',
#   'negocios',
#   'conjuntos',
#   'dados',
#   'complexos',
#   'grande',
#   'escala',
#   'forte',
#   'comunicacao',
#   'verbal',
#   'escrita',
#   'habilidades',
#   'apresentacao',
#   'dados',
#   'incluindo',
#   'capacidade',
#   'comunicar',
#   'eficazmente',
#   'equipes',
#   'negocios',
#   'tecnicas',
#   'historico',
#   'aprendizado',
#   'rapido',
#   'novas',
#   'tecnologias',
#   'paixao',
#   'aprender',
#   'usar',
#   'novas',
#   'tecnologias',
#   'prospera',
#   'ambiente',
#   'inovador',
#   'ritmo',
#   'acelerado'],
#  ['cientista_de_dados',
#   'resolver',
#   'problemas',
#   'complexos',
#   'curiosidade',
#   'explorar',
#   'quais',
#   'problemas',
#   'necessitam',
#   'solucao',
#   'conhecimento',
#   'conceitos',
#   'big',
#   'map',
#   'reduce',
#   'desenvolver',
#   'solucoes',
#   'python',
#   'spark',
#   'utilizando',
#   'principais',
#   'bibliotecas',
#   'analise',
#   'dados',
#   'possua',
#   'conhecimento',
#   'machine',
#   'learning',
#   'analise',
#   'exploracao',
#   'dados',
#   'idealmente',
#   'possua',
#   'tambem',
#   'conhecimentos',
#   'estatistica',
#   'probabilidade',
#   'saiba',
#   'utilizar',
#   'r'],
#  ['cientista_de_dados',
#   'atuar',
#   'metodos',
#   'modelagem',
#   'analise',
#   'estatisticas',
#   'series',
#   'temporais',
#   'modelos',
#   'lineares',
#   'arvore',
#   'decisao',
#   'analises',
#   'cluster',
#   'analises',
#   'exploratorias',
#   'analises',
#   'preditivas',
#   'analises',
#   'multivariadas',
#   'algoritmos',
#   'redes',
#   'neurais',
#   'mining',
#   'inferencia',
#   'bayesiana',
#   'linguagem',
#   'natural',
#   'outros',
#   'formacao',
#   'superior',
#   'completa',
#   'estatistica',
#   'engenharia',
#   'fisica',
#   'matematica',
#   'ciencias',
#   'computacao'],
#  ['cientista_de_dados',
#   'especialistas',
#   'analise',
#   'dados',
#   'habilidades',
#   'tecnicas',
#   'resolver',
#   'problemas',
#   'complexos',
#   'curiosidade',
#   'explorar',
#   'quais',
#   'problemas',
#   'necessitam',
#   'solucao',
#   'necessario',
#   'conhecimento',
#   'linguagens',
#   'python',
#   'r',
#   'java',
#   'script',
#   'conhecimentos',
#   'ciencias',
#   'dados',
#   'nlp',
#   'fuzzy',
#   'logica',
#   'nebulosa',
#   'nocoes',
#   'similaridade',
#   'redes',
#   'neurais',
#   'tensowflow',
#   'keras',
#   'modelos',
#   'classificacao',
#   'svm',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'modelos',
#   'clusterizacao',
#   'kmeans',
#   'dendogramacao',
#   'conhecimentos',
#   'orquestracao',
#   'nodered',
#   'nodejs',
#   'bancos',
#   'dados',
#   'mongodb',
#   'mysql',
#   'oracle',
#   'diferencias',
#   'otimizacao',
#   'matematica',
#   'cloudant',
#   'linguagem',
#   'julia',
#   'sas',
#   'spss',
#   'analise',
#   'dados'],
#  ['cientista_de_dados',
#   'desenvolver',
#   'novas',
#   'campanhas',
#   'estrategias',
#   'integrar',
#   'dados',
#   'orientadores',
#   'iniciativas',
#   'marketing',
#   'gerenciar',
#   'fazer',
#   'follow',
#   'up',
#   'todas',
#   'necessidades',
#   'areas',
#   'vendas',
#   'marketing',
#   'relacionado',
#   'analise',
#   'dados',
#   'desempenhar',
#   'coleta',
#   'dados',
#   'preparacao',
#   'dados',
#   'modelagem',
#   'checagem',
#   'qualidade',
#   'dados',
#   'analise',
#   'dados',
#   'desempenhar',
#   'dar',
#   'suporte',
#   'visualizacao',
#   'dados',
#   'buscar',
#   'padroes',
#   'dados',
#   'tendencia',
#   'criar',
#   'modelos',
#   'estatisticos',
#   'probabilidades',
#   'simulacoes',
#   'previsoes',
#   'arvore',
#   'decisao',
#   'regressao',
#   'linear',
#   'estatisticas',
#   'multivariadas',
#   'analises',
#   'preditivas',
#   'desenvolver',
#   'relatorios',
#   'kpi',
#   'reunir',
#   'requisitos',
#   'modelagem',
#   'publicacao',
#   'solucao',
#   'bi',
#   'apoiar',
#   'consultores',
#   'crm',
#   'insights',
#   'entendimento',
#   'dados',
#   'experiencia',
#   'hands',
#   'operacional',
#   'desenvolvimento',
#   'dados',
#   'marketing',
#   'experiencia',
#   'ciencia',
#   'dados',
#   'marketing',
#   'experiencia',
#   'pratica',
#   'modelagem',
#   'dados',
#   'marketing',
#   'rfv',
#   'lifetime',
#   'value',
#   'propensao',
#   'compra',
#   'afinidade',
#   'produto',
#   'forte',
#   'conhecimento',
#   'analitico',
#   'experiencia',
#   'relatorios',
#   'orientacao',
#   'insights',
#   'orientacao',
#   'otimizacao',
#   'dados',
#   'habilidade',
#   'converter',
#   'dados',
#   'insights',
#   'planos',
#   'acoes',
#   'sucesso',
#   'experiencia',
#   'r',
#   'python',
#   'excel',
#   'avancado',
#   'ensino',
#   'superior',
#   'completo',
#   'area',
#   'sistemas',
#   'estatistica'],
#  ['cientista_de_dados',
#   'identificar',
#   'avaliar',
#   'relevancia',
#   'preparar',
#   'fontes',
#   'dados',
#   'qualquer',
#   'tamanho',
#   'complexidade',
#   'preparar',
#   'dados',
#   'considerando',
#   'limpeza',
#   'enriquecimento',
#   'estruturacao',
#   'viabilizacao',
#   'amostragens',
#   'realizar',
#   'analises',
#   'exploratorias',
#   'dados',
#   'gerar',
#   'insights',
#   'propor',
#   'melhorias',
#   'otimizacoes',
#   'baseadas',
#   'mineracao',
#   'dados',
#   'investigar',
#   'interpretar',
#   'questoes',
#   'negocio',
#   'avaliar',
#   'melhores',
#   'tecnicas',
#   'serem',
#   'aplicadas',
#   'solucoes',
#   'utilizar',
#   'bi',
#   'apresentar',
#   'resultados',
#   'acompanhamento',
#   'outputs',
#   'algoritmos',
#   'criar',
#   'manter',
#   'warehouses',
#   'produzir',
#   'analises',
#   'detalhadas',
#   'sobre',
#   'comportamento',
#   'variaveis',
#   'criar',
#   'modelos',
#   'estatisticos',
#   'partir',
#   'fontes',
#   'diversas',
#   'dados',
#   'criar',
#   'rotinas',
#   'automatizar',
#   'extracao',
#   'processamento',
#   'dados',
#   'atuar',
#   'planejamento',
#   'estrategia',
#   'estruturacao',
#   'solucoes',
#   'big',
#   'estruturacao',
#   'lake',
#   'estruturar',
#   'modelos',
#   'machine',
#   'learning',
#   'apresentar',
#   'resultados',
#   'forma',
#   'estruturada',
#   'utilizando',
#   'todos',
#   'recursos',
#   'visuais',
#   'disponiveis',
#   'gerir',
#   'indicadores',
#   'performance',
#   'kpis',
#   'dashboards',
#   'criacao',
#   'manutencao',
#   'documentacao',
#   'solucoes',
#   'aplicadas',
#   'suportar',
#   'governanca',
#   'dados',
#   'estruturando',
#   'mantendo',
#   'dicionario',
#   'dados',
#   'experiencia',
#   'comprovada',
#   'bancos',
#   'dados',
#   'sql',
#   'sql',
#   'models',
#   'solidos',
#   'conhecimentos',
#   'conceituais',
#   'nosql',
#   'praticos',
#   'seguintes',
#   'solucoes',
#   'hbase',
#   'cassandra',
#   'riak',
#   'redis',
#   'mongodb',
#   'conhecimento',
#   'desenvolvimento',
#   'publicacao',
#   'manutencao',
#   'ferramentas',
#   'bi',
#   'tais',
#   'power',
#   'bi',
#   'google',
#   'cloud',
#   'tableau',
#   'klipfolio',
#   'qlink',
#   'experiencia',
#   'utilizacao',
#   'configuracao',
#   'ferramentas',
#   'etl',
#   'experiencia',
#   'plataformas',
#   'cloud',
#   'distribuidas',
#   'experiencia',
#   'comprovada',
#   'criacao',
#   'interpretacao',
#   'uso',
#   'modelos',
#   'matematicos',
#   'estatisticos',
#   'variadas',
#   'bibliotecas',
#   'atuais',
#   'python',
#   'r',
#   'tensor',
#   'flow',
#   'h2o',
#   'desejavel',
#   'conhecimento',
#   'sistema',
#   'mensagens',
#   'distribuidas',
#   'alto',
#   'rendimento',
#   'kafka',
#   'desejavel',
#   'conhecimento',
#   'ferramentas',
#   'digital',
#   'analytics',
#   'desejavel',
#   'conhecimento',
#   'aplicacoes',
#   'bibliotecas',
#   'machine',
#   'learning',
#   'tais',
#   'svm',
#   'deep',
#   'learning',
#   'azure',
#   'machine',
#   'learning',
#   'amazon',
#   'machine',
#   'learning',
#   'r',
#   'spark',
#   'ml',
#   'mllib',
#   'scikit',
#   'learn',
#   'assim',
#   'tecnicas',
#   'regressoes',
#   'sistemas',
#   'recomendacao',
#   'deep',
#   'learning',
#   'reinforcement',
#   'learning',
#   'sao',
#   'diferenciais',
#   'conhecimento',
#   'softwares',
#   'estatisticos',
#   'exemplo',
#   'minitab',
#   'familiaridade',
#   'mdm',
#   'aws',
#   'git',
#   'jira',
#   'jenkins',
#   'outras',
#   'ferramentas',
#   'devsecops',
#   'alem',
#   'metodologias',
#   'agile',
#   'scrum',
#   'conhecimentos',
#   'lgpd',
#   'gdpr',
#   'outras',
#   'regulamentacoes',
#   'relacionadas',
#   'dados',
#   'conhecimentos',
#   'avancados',
#   'excel',
#   'access',
#   'vba',
#   'automatizacao',
#   'relatorios',
#   'altamente',
#   'desejavel',
#   'certificacoes',
#   'exemplo',
#   'microsoft',
#   '70',
#   '767',
#   '70',
#   '768',
#   '70',
#   '775',
#   '70',
#   '778',
#   '70',
#   '779',
#   'mcsa',
#   'ibm',
#   'certified',
#   'archtecht',
#   'cap',
#   'aws',
#   'csa',
#   'tendo',
#   'sido',
#   'responsavel',
#   'estudos',
#   'diversas',
#   'bases',
#   'informacao',
#   'apresentado',
#   'resultados'],
#  ['cientista_de_dados',
#   'desenvolver',
#   'novas',
#   'campanhas',
#   'estrategias',
#   'integrar',
#   'dados',
#   'orientadores',
#   'iniciativas',
#   'marketing',
#   'gerenciar',
#   'fazer',
#   'follow',
#   'up',
#   'todas',
#   'necessidades',
#   'areas',
#   'vendas',
#   'marketing',
#   'relacionado',
#   'analise',
#   'dados',
#   'desempenhar',
#   'coleta',
#   'dados',
#   'preparacao',
#   'dados',
#   'modelagem',
#   'checagem',
#   'qualidade',
#   'dados',
#   'analise',
#   'dados',
#   'desempenhar',
#   'dar',
#   'suporte',
#   'visualizacao',
#   'dados',
#   'buscar',
#   'padroes',
#   'dados',
#   'tendencia',
#   'criar',
#   'modelos',
#   'estatisticos',
#   'probabilidades',
#   'simulacoes',
#   'previsoes',
#   'arvore',
#   'decisao',
#   'regressao',
#   'linear',
#   'estatisticas',
#   'multivariadas',
#   'analises',
#   'preditivas',
#   'desenvolver',
#   'relatorios',
#   'kpi',
#   'reunir',
#   'requisitos',
#   'modelagem',
#   'publicacao',
#   'solucao',
#   'bi',
#   'apoiar',
#   'consultores',
#   'crm',
#   'insights',
#   'entendimento',
#   'dados',
#   'experiencia',
#   'hands',
#   'operacional',
#   'desenvolvimento',
#   'dados',
#   'marketing',
#   'solida',
#   'experiencia',
#   'menos',
#   '3',
#   'anos',
#   'ciencia',
#   'dados',
#   'marketing',
#   'experiencia',
#   'pratica',
#   'modelagem',
#   'dados',
#   'marketing',
#   'rfv',
#   'lifetime',
#   'value',
#   'propensao',
#   'compra',
#   'afinidade',
#   'produto',
#   'forte',
#   'conhecimento',
#   'analitico',
#   'experiencia',
#   'relatorios',
#   'orientacao',
#   'insights',
#   'orientacao',
#   'otimizacao',
#   'dados',
#   'habilidade',
#   'converter',
#   'dados',
#   'insights',
#   'planos',
#   'acoes',
#   'sucesso',
#   'experiencia',
#   'r',
#   'python',
#   'excel',
#   'avancado',
#   'certificado',
#   'cientista',
#   'dados',
#   'certificado',
#   'analytics',
#   'professional',
#   'cap',
#   'ensino',
#   'superior',
#   'area',
#   'sistemas',
#   'estatistica'],
#  ['cientista_de_dados',
#   'lidar',
#   'volume',
#   'dados',
#   'diversas',
#   'fontes',
#   'diferentes',
#   'coletar',
#   'dados',
#   'serao',
#   'utilizados',
#   'analises',
#   'realizar',
#   'analise',
#   'exploratoria',
#   'dados',
#   'interagir',
#   'equipe',
#   'engenheiros',
#   'dados',
#   'selecionar',
#   'priorizar',
#   'entregas',
#   'selecionar',
#   'implantar',
#   'tecnicas',
#   'algoritmos',
#   'machine',
#   'learning',
#   'ia',
#   'resolucao',
#   'problemas',
#   'selecionados',
#   'trabalhar',
#   'adotando',
#   'metodologias',
#   'ageis',
#   'desenvolver',
#   'reportar',
#   'relatorios',
#   'justificar',
#   'tecnicas',
#   'adotadas',
#   'realizar',
#   'visitas',
#   'interacoes',
#   'clientes',
#   'fim',
#   'entender',
#   'real',
#   'necessidade',
#   'formacao',
#   'estatistica',
#   'engenharia',
#   'fisica',
#   'matematica',
#   'ciencias',
#   'computacao',
#   'conhecimentos',
#   'banco',
#   'dados',
#   'relacionais',
#   'sql',
#   'server',
#   'mysql',
#   'postgresql',
#   'nao',
#   'relacionais',
#   'mongodb',
#   'experiencia',
#   'r',
#   'python',
#   'conhecimentos',
#   'ferramentas',
#   'im'],
#  ['cientista_de_dados',
#   'tecnicas',
#   'machine',
#   'learning',
#   'manipulacao',
#   'transformacao',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'compreensao',
#   'estatistica',
#   'incluindo',
#   'testes',
#   'distribuicoes',
#   'dominio',
#   'linguagens',
#   'programacao',
#   'python',
#   'r',
#   'desejavel',
#   'conhecimentos',
#   'spark',
#   'hadoop',
#   'gestao',
#   'projetos',
#   'formacao',
#   'matematica',
#   'estatistica',
#   'fisica',
#   'engenharia',
#   'ciencias',
#   'computacao'],
#  ['cientista_de_dados',
#   'gigante',
#   'nacional',
#   'atuante',
#   'segmento',
#   'servicos',
#   'saude',
#   'vasta',
#   'area',
#   'tecnologia',
#   'busca',
#   'cientista',
#   'dados',
#   'experiencia',
#   'relevante',
#   'logica',
#   'programacao',
#   'profissional',
#   'ira',
#   'atuar',
#   'celula',
#   'inteligencia',
#   'artificial',
#   'empresa',
#   'desenvolvimento',
#   'modelos',
#   'analise',
#   'preditiva',
#   'utilizando',
#   'machine',
#   'learning',
#   'inteligencia',
#   'artificial',
#   'gerar',
#   'analises',
#   'insights',
#   'tragam',
#   'valor',
#   'financeiro',
#   'imagem',
#   'inovacao',
#   'companhia',
#   'desenvolver',
#   'dashboards',
#   'complexos',
#   'nao',
#   'visem',
#   'melhora',
#   'operacional',
#   'aumento',
#   'receita',
#   'reducao',
#   'custo',
#   'processos',
#   'companhia',
#   'apoiar',
#   'areas',
#   'internas',
#   'companhia',
#   'desenvolvimento',
#   'visao',
#   'analitica',
#   'dados',
#   'analise',
#   'estatistica',
#   'matematica',
#   'otimizacao',
#   'estruturar',
#   'tratar',
#   'correlacionar',
#   'diferentes',
#   'bancos',
#   'dados',
#   'disseminar',
#   'conceito',
#   'democratizacao',
#   'dados',
#   'dentro',
#   'companhia',
#   'estar',
#   'atento',
#   'constante',
#   'busca',
#   'inovacao',
#   'conhecimentos',
#   'excel',
#   'r',
#   'python',
#   'sql',
#   'ferramentas',
#   'bi',
#   'tableau',
#   'power',
#   'bi',
#   'logica',
#   'programacao',
#   'banco',
#   'dados',
#   'sql',
#   'desenvolvimento',
#   'r',
#   'pyhton',
#   'conhecimento',
#   'metodos',
#   'machine',
#   'learning',
#   'bi',
#   'estatistica',
#   'avancada'],
#  ['cientista_de_dados',
#   'stefanini',
#   'labs',
#   'celula',
#   'inovacao',
#   'stefanini',
#   'busca',
#   'cientista',
#   'dados',
#   'compor',
#   'necessario',
#   'conhecimento',
#   'linguagens',
#   'python',
#   'r',
#   'java',
#   'script',
#   'conhecimentos',
#   'ciencias',
#   'dados',
#   'nlp',
#   'fuzzy',
#   'logica',
#   'nebulosa',
#   'nocoes',
#   'similaridade',
#   'atuar',
#   'redes',
#   'neurais',
#   'tensowflow',
#   'keras',
#   'modelos',
#   'classificacao',
#   'svm',
#   'random',
#   'forest',
#   'logistic',
#   'regression',
#   'modelos',
#   'clusterizacao',
#   'kmeans',
#   'dendogramacao',
#   'conhecimentos',
#   'orquestracao',
#   'nodered',
#   'nodejs',
#   'bancos',
#   'dados',
#   'mongodb',
#   'mysql',
#   'oracle',
#   'ingles',
#   'avancado',
#   'diferencias',
#   'otimizacao',
#   'matematica',
#   'cloudant',
#   'linguagem',
#   'julia',
#   'sas',
#   'spss',
#   'analise',
#   'dados'],
#  ['cientista_de_dados',
#   'desenvolver',
#   'modelos',
#   'estatisticos',
#   'exploracao',
#   'dados',
#   'diversas',
#   'origens',
#   'gerando',
#   'insights',
#   'identificando',
#   'oportunidades',
#   'melhoria',
#   'processos',
#   'resultados',
#   'ponto',
#   'focal',
#   'contato',
#   'areas',
#   'negocio',
#   'mapeando',
#   'necessidades',
#   'informacao',
#   'transformando',
#   'solucao',
#   'analitica',
#   'simplificacao',
#   'metodos',
#   'exploracao',
#   'utilizando',
#   'tecnicas',
#   'estatisticas',
#   'desenvolver',
#   'processos',
#   'etl',
#   'utilizando',
#   'melhores',
#   'praticas',
#   'modelagem',
#   'bi',
#   'suportar',
#   'todos',
#   'processos',
#   'governanca',
#   'dados',
#   'suportar',
#   'planejamento',
#   'definicao',
#   'estrategia',
#   'estruturacao',
#   'lake',
#   'solucoes',
#   'big',
#   'inteligencia',
#   'artificial',
#   'machine',
#   'learning',
#   'formacao',
#   'superior',
#   'engenharia',
#   'estatistica',
#   'matematica',
#   'ciencia',
#   'computacao',
#   'areas',
#   'correlatas',
#   'diferencial',
#   'especializacao',
#   'ciencia',
#   'dados',
#   'big',
#   'experiencia',
#   'linguagens',
#   'manipulacao',
#   'dados',
#   'sql',
#   'estatistica',
#   'python',
#   'sas',
#   'r',
#   'desejaveis',
#   'conhecimentos',
#   'machine',
#   'learning',
#   'plataforma',
#   'hadoop',
#   'desejavel',
#   'conhecimento',
#   'ferramentas',
#   'bi',
#   'preferencialmente',
#   'tableau',
#   'alteryx',
#   'metodologias',
#   'ageis',
#   'kanban',
#   'scrum',
#   'desenho',
#   'processos',
#   'negocio'],
#  ['cientista_de_dados',
#   'levantamento',
#   'documentacao',
#   'requisitos',
#   'captura',
#   'manipulacao',
#   'dados',
#   'tratamento',
#   'higienizacao',
#   'dados',
#   'funcao',
#   'principal',
#   'criacao',
#   'arquitetura',
#   'coleta',
#   'transformacao',
#   'dados',
#   'informacoes',
#   'confiaveis',
#   'exploracao',
#   'analises',
#   'descritivas',
#   'garantir',
#   'entregas',
#   'dentro',
#   'prazo',
#   'qualidade',
#   'dominio',
#   'python',
#   'dominio',
#   'sql',
#   'spark',
#   'desejavel',
#   'intelligence',
#   'big',
#   'modelos',
#   'estatisticos',
#   'diferencial',
#   'desejavel',
#   'conhecimento',
#   'call',
#   'center'],
#  ['cientista_de_dados',
#   'responsavel',
#   'pesquisa',
#   'gerenciamento',
#   'organizacao',
#   'dados',
#   'desafio',
#   'desenhar',
#   'arquitetar',
#   'treinar',
#   'desenvolver',
#   'modelos',
#   'machine',
#   'learning',
#   'desde',
#   'simples',
#   'knn',
#   'clustering',
#   'ate',
#   'algoritmos',
#   'complexos',
#   'redes',
#   'neurais',
#   'nlp',
#   'deep',
#   'learning',
#   'capacidade',
#   'transmitir',
#   'ideias',
#   'complexas',
#   'diversos',
#   'tipos',
#   'publicos',
#   'desejavel',
#   'vivencia',
#   'mercado',
#   'financeiro',
#   'tradicional',
#   'criptomoedas',
#   'ensino',
#   'superior',
#   'completo',
#   'matematica',
#   'fisica',
#   'engenharia',
#   'ciencias',
#   'computacao',
#   'areas',
#   'correlatas',
#   'pos',
#   'graduacao',
#   'mba',
#   'mestrado',
#   'doutorado',
#   'pos',
#   'doutorado',
#   'serao',
#   'considerados',
#   'diferenciais'],
#  ['cientista_de_dados',
#   'atuar',
#   'mineracao',
#   'dados',
#   'mining',
#   'estatistica',
#   'ms',
#   'excel',
#   'programacao',
#   'vba',
#   'sql',
#   'mathlab',
#   'outra',
#   'ferramenta',
#   'analise',
#   'dados',
#   'ensino',
#   'superior',
#   'estatistica',
#   'ciencia',
#   'computacao',
#   'sistemas',
#   'informacao',
#   'engenharia',
#   'computacao',
#   'similares'],
#  ['cientista_de_dados',
#   'mindset',
#   'empreendedor',
#   'postura',
#   'dono',
#   'responsavel',
#   'entrega',
#   'projetos',
#   'adaptavel',
#   'aprender',
#   'rapido',
#   'entender',
#   'contexto',
#   'big',
#   'picture',
#   'conseguir',
#   'aplicar',
#   'abordagens',
#   'box',
#   'atingir',
#   'objetivos',
#   'projetar',
#   'implementar',
#   'modelos',
#   'aprendizado',
#   'alem',
#   'acompanhar',
#   'desenvolvedores',
#   'menos',
#   'experientes',
#   'durante',
#   'desenvolvimento',
#   'produto',
#   'utilizar',
#   'tecnicas',
#   'exploracao',
#   'dados',
#   'descobrir',
#   'novas',
#   'questoes',
#   'oportunidades',
#   'dentro',
#   'area',
#   'problema',
#   'propor',
#   'aplicabilidade',
#   'desenvolver',
#   'alto',
#   'padrao',
#   'focado',
#   'entregas',
#   'qualidade',
#   'cobertura',
#   'codigo',
#   'testes',
#   'automatizados',
#   'integracao',
#   'continua',
#   'desenvolver',
#   'executar',
#   'planos',
#   'testes',
#   'validacao',
#   'aplicacoes',
#   'revisar',
#   'resultado',
#   'testes',
#   'servir',
#   'lider',
#   'projeto',
#   'lider',
#   'tecnico',
#   'durante',
#   'decorrer',
#   'projetos',
#   'apoiar',
#   'desenvolvedores',
#   'menos',
#   'experientes',
#   'atingir',
#   'objetivos',
#   'respeitando',
#   'sempre',
#   'requisitos',
#   'engenharia',
#   'arquitetura',
#   'qualidade',
#   'experiencia',
#   'ciencia',
#   'dados',
#   'programacao',
#   'python',
#   'mestrado',
#   'areas',
#   'voltadas',
#   'aprendizagem',
#   'maquina',
#   'formacao',
#   'ensino',
#   'superior',
#   'ciencia',
#   'computacao',
#   'equivalente',
#   'ingles',
#   'tecnico',
#   'leitura',
#   'escrita',
#   'experiencia',
#   'linux',
#   'unix',
#   'experiencia',
#   'plataforma',
#   'docker',
#   'images',
#   'containers',
#   'experiencia',
#   'aws',
#   's3',
#   'ec2',
#   'ecs',
#   'sqs',
#   'cloudwatch',
#   'python',
#   'numpy',
#   'scipy',
#   'pandas',
#   'psycopg2',
#   'sklearn',
#   'keras',
#   'tensorflow',
#   'sql',
#   'nosql',
#   'databases',
#   'postgres',
#   'sql',
#   'server',
#   'redshift',
#   'experiencia',
#   'ferramentas',
#   'gerenciamento',
#   'workflow',
#   'airflow',
#   'luigi',
#   'experiencia',
#   'inferencia',
#   'estatistica',
#   'experiencia',
#   'aprendizado',
#   'maquina',
#   'supervisionado',
#   'nao',
#   'supervisionado',
#   'experiencia',
#   'modelagem',
#   'features',
#   'feature',
#   'feature',
#   'selection',
#   'feature',
#   'weighting',
#   'experiencia',
#   'sistemas',
#   'recomendacao'],
#  ['cientista_de_dados',
#   'projetar',
#   'implementar',
#   'modelos',
#   'aprendizado',
#   'alem',
#   'acompanhar',
#   'desenvolvedores',
#   'menos',
#   'experientes',
#   'durante',
#   'desenvolvimento',
#   'produto',
#   'utilizar',
#   'tecnicas',
#   'exploracao',
#   'dados',
#   'descobrir',
#   'novas',
#   'questoes',
#   'oportunidades',
#   'dentro',
#   'area',
#   'problema',
#   'propor',
#   'aplicabilidade',
#   'experiencia',
#   'ciencia',
#   'dados',
#   'programacao',
#   'python'],
#  ['cientista_de_dados',
#   'cientista',
#   'dados',
#   'funcao',
#   'area',
#   'ti',
#   'reporta',
#   'diretamente',
#   'gerente',
#   'global',
#   'desempenhara',
#   'papel',
#   'fundamental',
#   'planejamento',
#   'execucao',
#   'entrega',
#   'projetos',
#   'baseados',
#   'aprendizado',
#   'maquina',
#   'maior',
#   'parte',
#   'trabalho',
#   'sera',
#   'modelagem',
#   'aprendizado',
#   'maquina',
#   'ml',
#   'gerenciamento',
#   'analise',
#   'problemas',
#   'exploracao',
#   'preparacao',
#   'dados',
#   'coleta',
#   'integracao',
#   'dados',
#   'bem',
#   'operacionalizacao',
#   'cientista',
#   'dados',
#   'sera',
#   'interface',
#   'chave',
#   'area',
#   'comercial',
#   'industrial',
#   'principalmente',
#   'equipe',
#   'ti',
#   'unidade',
#   'negocio',
#   'varios',
#   'outros',
#   'departamentos',
#   'lancamento',
#   'projetos',
#   'significativos',
#   'ciencia',
#   'dados',
#   'gerenciar',
#   'projetos',
#   'todos',
#   'portes',
#   'ciencia',
#   'dados',
#   'equipes',
#   'diversas',
#   'projetos',
#   'aplicacao',
#   'ml',
#   'ciencia',
#   'dados',
#   'funcoes',
#   'negocios',
#   'tais',
#   'automacao',
#   'call',
#   'center',
#   'otimizacao',
#   'sites',
#   'analises',
#   'risco',
#   'financeiro',
#   'logistica',
#   'fabricacao',
#   'emprestimos',
#   'seguros',
#   'analises',
#   'jornadas',
#   'clientes',
#   'marketing',
#   'analise',
#   'avaliacao',
#   'qualidade',
#   'automacao',
#   'producao',
#   'plataformas',
#   'commerce',
#   'logistica',
#   'armazem',
#   'controle',
#   'robo',
#   'fisico',
#   'controle',
#   'processo',
#   'marketing',
#   'destino',
#   'gerenciamento',
#   'rotatividade',
#   'experiencia',
#   'linguagens',
#   'programacao',
#   'bancos',
#   'dados',
#   'populares',
#   'incluindo',
#   'sql',
#   'pl',
#   'sql',
#   'outros',
#   'bancos',
#   'dados',
#   'relacionais',
#   'futuros',
#   'bancos',
#   'dados',
#   'nao',
#   'relacionais',
#   'bancos',
#   'dados',
#   'orientados',
#   'nosql',
#   'hadoop',
#   'mongodb',
#   'cassandra',
#   'outros',
#   'experiencia',
#   'trabalho',
#   'varios',
#   'ambientes',
#   'implementacao',
#   'incluindo',
#   'nuvem',
#   'local',
#   'hibrido',
#   'varios',
#   'sistemas',
#   'operacionais',
#   'tecnicas',
#   'conteiner',
#   'docker',
#   'kubernetes',
#   'aws',
#   'elastic',
#   'container',
#   'outros',
#   'experiencia',
#   'projetos',
#   'relevantes',
#   'ciencias',
#   'dados',
#   'bem',
#   'sucedidos',
#   'lancando',
#   'planejando',
#   'executando',
#   'preferencialmente',
#   'dominios',
#   'modelagem',
#   'risco',
#   'previsao',
#   'comportamento',
#   'cliente',
#   'avaliacao',
#   'qualidade',
#   'automacao',
#   'fabrica',
#   'conhecimento',
#   'metodologias',
#   'ageis',
#   'bem',
#   'versados',
#   'aplicacao',
#   'metodos',
#   'devops',
#   'mlops',
#   'construcao',
#   'pipelines',
#   'ml',
#   'science',
#   'ensino',
#   'superior',
#   'ciencia',
#   'computacao',
#   'ciencia',
#   'dados',
#   'pesquisa',
#   'operacional',
#   'estatistica',
#   'matematica',
#   'aplicada',
#   'outras',
#   'areas',
#   'correlatas',
#   'conhecimento',
#   'experiencia',
#   'codificar',
#   'varias',
#   'linguagens',
#   'exemplo',
#   'r',
#   'python',
#   'jupyter',
#   'sas',
#   'java',
#   'scala',
#   'c',
#   'excel',
#   'matlab',
#   'experiencia',
#   'ferramentas',
#   'distribuidas',
#   'dados',
#   'computacao',
#   'mapreduce',
#   'hadoop',
#   'hive',
#   'kafka',
#   'tambem',
#   'mysql',
#   'ingles',
#   'fluente',
#   'avancado',
#   'conhecimento',
#   'linguagem',
#   'abap',
#   'bw',
#   'analise',
#   'texto',
#   'reconhecimento',
#   'imagem',
#   'analise',
#   'graficos',
#   'outras',
#   'tecnicas',
#   'especializadas',
#   'ml',
#   'aprendizagem',
#   'profunda'],
#  ['data_science', 'it\\'],
# ...
#   'patricia',
#   'matheus',
#   'secretaria',
#   'ibope',
#   'dtm'],
#  ['cientista_de_dados',
#   'requisitos',
#   'linguagens',
#   'python',
#   'r',
#   'estatistica',
#   'basica',
#   'conhecimento',
#   'sobre',
#   'medias',
#   'medianas',
#   'quartis',
#   'desvio',
#   'padrao',
#   'probabilidade',
#   'testes',
#   'estatisticos',
#   'outros',
#   'conceitos',
#   'aprendizado',
#   'maquina',
#   'conhecimento',
#   'principais',
#   'algoritmos',
#   'utiliza',
#   'los',
#   'forma',
#   'correta',
#   'realizar',
#   'experimentos',
#   'engenharia',
#   'features',
#   'desejavel',
#   'sql',
#   'demonstrar',
#   'experiencia',
#   'hadoop',
#   'spark',
#   'demonstrar',
#   'experiencia',
#   'bancos',
#   'dados',
#   'nosql',
#   'mongodb',
#   'cassandra',
#   'neo4j',
#   'profissional',
#   'pj',
#   'prazo',
#   'indeterminado',
#   'local',
#   'butanta',
#   'proximo',
#   'usp'],
#  ['cientista_de_dados',
#   'requisitos',
#   'necessarios',
#   'matematica',
#   'algebra',
#   'linear',
#   'calculo',
#   'basicolinguagens',
#   'python',
#   'javaexperiencia',
#   'utilizacao',
#   'pratica',
#   'principais',
#   'familias',
#   'algoritmos',
#   'machine',
#   'learning',
#   'science',
#   'regressao',
#   'classificacao',
#   'clustering',
#   'redes',
#   'neurais',
#   'nlp',
#   'mining',
#   'feature',
#   'model',
#   'evaluation',
#   'etcdeep',
#   'learning',
#   'cnn',
#   'rnn',
#   'lstmframeworks',
#   'tensorflow',
#   'scikit',
#   'learn',
#   'pytorchplataformas',
#   'jupyter',
#   'notebook',
#   'anaconda',
#   'assistentes',
#   'virtuais'],
#  ['cientista_de_dados',
#   'responsavel',
#   'pesquisa',
#   'gerenciamento',
#   'organizacao',
#   'dados',
#   'desafio',
#   'desenhar',
#   'arquitetar',
#   'treinar',
#   'desenvolver',
#   'modelos',
#   'machine',
#   'learning',
#   'desde',
#   'simples',
#   'knn',
#   'clustering',
#   'ate',
#   'algoritmos',
#   'complexos',
#   'redes',
#   'neurais',
#   'nlp',
#   'deep',
#   'learning',
#   'conhecimento',
#   'avancado',
#   'python',
#   'r',
#   'spark',
#   'sql',
#   'habilidade',
#   'compreender',
#   'abstrair',
#   'conceitos',
#   'matematicos',
#   'estatisticos',
#   'forma',
#   'profunda',
#   'alem',
#   'tera',
#   'funcao',
#   'implementar',
#   'gerenciar',
#   'suportar',
#   'modelos',
#   'machine',
#   'learning',
#   'forma',
#   'escalavel',
#   'postura',
#   'fortemente',
#   'analitica',
#   'sendo',
#   'capaz',
#   'organizar',
#   'partes',
#   'problema',
#   'fazendo',
#   'comparacoes',
#   'questionamentos',
#   'identificando',
#   'relacoes',
#   'causa',
#   'efeito',
#   'determinando',
#   'pontos',
#   'relevantes',
#   'situacoes',
#   'complexas',
#   'curiosidade',
#   'intelectual',
#   'forte',
#   'disposicao',
#   'pensar',
#   'agir',
#   'caixa',
#   'elaborando',
#   'analises',
#   'foco',
#   'solucao',
#   'problemas',
#   'especificos',
#   'capacidade',
#   'transmitir',
#   'ideias',
#   'complexas',
#   'diversos',
#   'tipos',
#   'publicos',
#   'desejavel',
#   'vivencia',
#   'mercado',
#   'financeiro',
#   'tradicional',
#   'criptomoedas',
#   'ensino',
#   'superior',
#   'completo',
#   'matematica',
#   'fisica',
#   'engenharia',
#   'ciencias',
#   'computacao',
#   'areas',
#   'correlatas',
#   'pos',
#   'graduacao',
#   'mba',
#   'mestrado',
#   'doutorado',
#   'pos',
#   'doutorado',
#   'serao',
#   'considerados',
#   'diferenciais',
#   'oferecemos',
#   'salario',
#   'clt',
#   'avaliaremos',
#   'pretensao',
#   'salarial',
#   'x',
#   'expertise',
#   'vale',
#   'refeicao',
#   'r',
#   '45',
#   '00',
#   'dia',
#   'assistencia',
#   'medica',
#   'odontologica',
#   'sulamerica',
#   'auxilio',
#   'educacao',
#   'idiomas',
#   'ate',
#   'r',
#   '400',
#   '00',
#   'mes',
#   'auxilio',
#   'faculdade',
#   'pos',
#   'graduacao',
#   '80',
#   'limitado',
#   'r',
#   '800',
#   '00',
#   'mes',
#   'queremos',
#   'profissionais',
#   'sempre',
#   'atualizados',
#   'snacks',
#   'bebidas',
#   'free',
#   'escritorio',
#   'pagamento',
#   'semanal',
#   'horario',
#   'flexivel',
#   'celular',
#   'plano',
#   'corporativo',
#   'iphone',
#   'convenio',
#   'gympass',
#   'dress',
#   'code',
#   'aqui',
#   'voce',
#   'pode',
#   'trabalhar',
#   'camiseta',
#   'bermuda',
#   'afinal',
#   'importa',
#   'resultado',
#   'achou',
#   'oportunidade',
#   'cara',
#   'queremos',
#   'conhecer'],
#  ['cientista_de_dados',
#   'construir',
#   'avaliar',
#   'executar',
#   'scripts',
#   'atualizacao',
#   'dados',
#   'forma',
#   'performatica',
#   'garantir',
#   'melhores',
#   'praticas',
#   'relacao',
#   'modelagem',
#   'persistencia',
#   'dados',
#   'conhecer',
#   'modelo',
#   'regras',
#   'negocio',
#   'garantir',
#   'governanca',
#   'informacao',
#   'atuar',
#   'juntos',
#   'desenvolvedores',
#   'administradores',
#   'dados',
#   'cientistas',
#   'dados',
#   'equipe',
#   'infra',
#   'product',
#   'owner',
#   'fim',
#   'criar',
#   'solucoes',
#   'dados',
#   'catalogar',
#   'produtos',
#   'servicos',
#   'garantir',
#   'integracao',
#   'dados',
#   'possibilitar',
#   'cruzamento',
#   'informacoes',
#   'acompanhamento',
#   'metricas',
#   'garantir',
#   'politicas',
#   'seguranca',
#   'estao',
#   'sendo',
#   'aplicadas',
#   'camada',
#   'acesso',
#   'dados',
#   'fomentar',
#   'utilizacao',
#   'tecnicas',
#   'automacao',
#   'provisionamento',
#   'configuracao',
#   'monitoramento',
#   'ambientes',
#   'banco',
#   'dados',
#   'principais',
#   'requisitos',
#   'superior',
#   'completo',
#   'tecnologia',
#   'informacao',
#   'engenharia',
#   'computacao',
#   'ciencia',
#   'computacao',
#   'areas',
#   'correlatas',
#   'conhecimento',
#   'java',
#   'sql',
#   'linux',
#   'shell',
#   'experiencia',
#   'projetos',
#   'big',
#   'processamento',
#   'distribuido',
#   'hdfs',
#   'hive',
#   'impala',
#   'hbase',
#   'spark',
#   'kafka',
#   'scala',
#   'sqoop',
#   'storm',
#   'experiencia',
#   'ambientes',
#   'alta',
#   'criticidade',
#   'conhecimento',
#   'modelagem',
#   'dados',
#   'relacional',
#   'nao',
#   'relacional',
#   'experiencia',
#   'banco',
#   'dados',
#   'oracle',
#   'sql',
#   'server',
#   'mysql',
#   'cultura',
#   'devops',
#   'fazer',
#   'parte',
#   'devops',
#   'aprender',
#   'outras',
#   'tecnologias',
#   'persistencia',
#   'dados',
#   'sao',
#   'considerados',
#   'diferenciais',
#   'experiencia',
#   'banco',
#   'dados',
#   'nosql',
#   'hbase',
#   'cassandra',
#   'mongodb',
#   'experiencia',
#   'ferramentas',
#   'etl',
#   'integracao',
#   'dados',
#   'conhecimento',
#   'ferramentas',
#   'gestao',
#   'dados',
#   'ciclo',
#   'vida',
#   'dados',
#   'replicacoes',
#   'dados',
#   'real',
#   'mascaramento',
#   'dados',
#   'conhecimento',
#   'sistemas',
#   'distribuidos',
#   'aplicacoes',
#   'web',
#   'oferecemos',
#   'salario',
#   'clt',
#   'avaliaremos',
#   'pretensao',
#   'salarial',
#   'x',
#   'expertise',
#   'vale',
#   'refeicao',
#   'r',
#   '45',
#   '00',
#   'dia',
#   'assistencia',
#   'medica',
#   'odontologica',
#   'sulamerica',
#   'auxilio',
#   'educacao',
#   'idiomas',
#   'ate',
#   'r',
#   '400',
#   '00',
#   'mes',
#   'auxilio',
#   'faculdade',
#   'pos',
#   'graduacao',
#   '80',
#   'limitado',
#   'r',
#   '800',
#   '00',
#   'mes',
#   'queremos',
#   'profissionais',
#   'sempre',
#   'atualizados',
#   'snacks',
#   'bebidas',
#   'free',
#   'escritorio',
#   'pagamento',
#   'semanal',
#   'horario',
#   'flexivel',
#   'celular',
#   'plano',
#   'corporativo',
#   'iphone',
#   'convenio',
#   'gympass',
#   'dress',
#   'code',
#   'aqui',
#   'voce',
#   'pode',
#   'trabalhar',
#   'camiseta',
#   'bermuda',
#   'afinal',
#   'importa',
#   'resultado',
#   'achou',
#   'oportunidade',
#   'cara',
#   'queremos',
#   'conhecer'],
#  ['cientista_de_dados',
#   'venha',
#   'fazer',
#   'parte',
#   'grupo',
#   'itg',
#   'aqui',
#   'trabalhamos',
#   'alteryx',
#   'lider',
#   'rapido',
#   'crescimento',
#   'catalogacao',
#   'dados',
#   'preparacao',
#   'analise',
#   'avancada',
#   'modelagem',
#   'quebrando',
#   'barreiras',
#   'processo',
#   'analises',
#   'capacitando',
#   'centenas',
#   'analistas',
#   'unica',
#   'empresa',
#   'tornarem',
#   'citizen',
#   'scientists',
#   'ate',
#   'ajudando',
#   'cientistas',
#   'dados',
#   'chegar',
#   'respostas',
#   'rapidamente',
#   'buscamos',
#   'profissional',
#   'engajado',
#   'motivado',
#   'obter',
#   'novos',
#   'aprendizados',
#   'conhecimento',
#   'ferramentas',
#   'atuais',
#   'revolucionam',
#   'mercado',
#   'alteryx',
#   'profissional',
#   'atuara',
#   'maiores',
#   'empresas',
#   'pais',
#   'indispensavel',
#   'avesso',
#   'comodismo',
#   'buscar',
#   'sempre',
#   'ha',
#   'inovador',
#   'mercado',
#   'voce',
#   'identificou',
#   'perfil',
#   'sera',
#   'prazer',
#   'lo',
#   'acompanhe',
#   'descricao',
#   'vaga',
#   'faca',
#   'inscricao',
#   'processo',
#   'seletivo',
#   'principais',
#   'responsabilidades',
#   'desenvolvimento',
#   'modelos',
#   'preditivos',
#   'possibilitem',
#   'nossos',
#   'clientes',
#   'tomem',
#   'decisoes',
#   'relevantes',
#   'atuar',
#   'desde',
#   'levantamento',
#   'requisitos',
#   'desenho',
#   'projeto',
#   'desenvolvimento',
#   'solucao',
#   'portanto',
#   'atuando',
#   'equipes',
#   'tecnicas',
#   'nao',
#   'tecnicas',
#   'diversas',
#   'areas',
#   'capacidade',
#   'lidar',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'qualificacoes',
#   'necessarias',
#   'analise',
#   'dados',
#   'inteligencia',
#   'negocios',
#   'interesse',
#   'ferramenta',
#   'bi',
#   'experiencia',
#   'modelagem',
#   'dados',
#   'experiencia',
#   'ti',
#   'voltada',
#   'negocio',
#   'ingles',
#   'avancado',
#   'desejavel',
#   'ferramentas',
#   'bi',
#   'etl',
#   'datawarehouse',
#   'conhecimento',
#   'alteryx',
#   'experiencia',
#   'modelagem',
#   'estatistica',
#   'utilizando',
#   'r',
#   'python',
#   'espanhol',
#   'avancado'],
#  ['cientista_de_dados',
#   'principais',
#   'atividades',
#   'requisitos',
#   'minerar',
#   'analisar',
#   'grande',
#   'volume',
#   'dados',
#   'uso',
#   'dados',
#   'propor',
#   'melhorias',
#   'produto',
#   'atualizacao',
#   'relatorios',
#   'diversos',
#   'analises',
#   'formacao',
#   'superior',
#   'estatistica',
#   'matematica',
#   'ciencias',
#   'computacao',
#   'engenharia',
#   'cursos',
#   'relacionados',
#   'tecnologia',
#   'informacao',
#   'ingles',
#   'intermediarioo',
#   'conhecimento',
#   'linguagens',
#   'programacao',
#   'r',
#   'phyton',
#   'sql',
#   'conhecimento',
#   'estatistica',
#   'modelos',
#   'preditivos',
#   'analises',
#   'probabilisticas',
#   'requisitos',
#   'desejaveis',
#   'conhecimento',
#   'ferramenta',
#   'spss',
#   'conhecimento',
#   'bancos',
#   'dados',
#   'oracle',
#   'mysql',
#   'experiencia',
#   'big',
#   'query'],
#  ['cientista_de_dados',
#   'formacao',
#   'academica',
#   'ensino',
#   'superior',
#   'completo',
#   'administracao',
#   'estatistica',
#   'matematica',
#   'ciencias',
#   'computacao',
#   'areas',
#   'afinspre',
#   'requisitos',
#   'experiencia',
#   'analises',
#   'grande',
#   'volume',
#   'dados',
#   'sql',
#   'access',
#   'referentes',
#   'comportamento',
#   'clientesatuacao',
#   'estrategias',
#   'ferramentas',
#   'capazes',
#   'aumentar',
#   'rentabilidade',
#   'clientesconhecimento',
#   'mineracao',
#   'dados',
#   'clustering',
#   'arvore',
#   'decisao',
#   'linguagens',
#   'programacao',
#   'analytics',
#   'r',
#   'python',
#   'sas',
#   'pacote',
#   'avancado',
#   'principalmente',
#   'exceldesejavel',
#   'conhecimento',
#   'mercado',
#   'seguradorprincipais',
#   'responsabilidades',
#   'desenhar',
#   'padronizar',
#   'documentar',
#   'processos',
#   'entrada',
#   'processamento',
#   'dados',
#   'etls',
#   'tratamento',
#   'mineracao',
#   'dadoshigienizacao',
#   'deduplicacao',
#   'dadosprocessos',
#   'monitoria',
#   'alerta',
#   'cargas',
#   'dadosestruturacao',
#   'datalake',
#   'dados',
#   'estruturados',
#   'nao',
#   'estruturados',
#   'viabilizar',
#   'ambiente',
#   'analitycs',
#   'geracao',
#   'analisesrealizar',
#   'analises',
#   'dados',
#   'historicos',
#   'desempenho',
#   'negocio',
#   'base',
#   'modelagens',
#   'simulacoesdefinir',
#   'implementar',
#   'realizar',
#   'manutencao',
#   'modelos',
#   'estatisticos',
#   'maior',
#   'assertividade',
#   'acordo',
#   'demanda',
#   'recebidacriacao',
#   'indicadores',
#   'performance',
#   'acompanhar',
#   'todas',
#   'acoes',
#   'venda',
#   'relacionamentoidentificar',
#   'oportunidades',
#   'novos',
#   'negocios',
#   'atraves',
#   'resultados',
#   'obtidoscriacao',
#   'dashboards',
#   'reproduzam',
#   'conhecimento',
#   'sobre',
#   'perfil',
#   'cliente',
#   'comportamento',
#   'cada',
#   'linha',
#   'negocioapoiar',
#   'conducao',
#   'projeto',
#   'cadastro',
#   'unicoimplementar',
#   'documentos',
#   'garantam',
#   'governanca',
#   'dados',
#   'utilizados',
#   'empresaapoiar',
#   'areas',
#   'negocio',
#   'criacao',
#   'sumarios',
#   'executivos',
#   'fundamentados',
#   'dados',
#   'suportem',
#   'tomada',
#   'decisaopacote',
#   'beneficios',
#   'assistencia',
#   'medicaassistencia',
#   'odontologicavale',
#   'alimentacaovale',
#   'refeicaovale',
#   'transporteauxilio',
#   'creche',
#   'babaservico',
#   'assistencia',
#   'funeralseguro',
#   'vidaprevidencia',
#   'privadabonus',
#   'curto',
#   'prazo',
#   'plr',
#   'local',
#   'trabalho',
#   'centro',
#   'rj'],
#  ['cientista_de_dados',
#   'descricaoatuar',
#   'interface',
#   'area',
#   'negocios',
#   'cientistas',
#   'dados',
#   'auxiliar',
#   'desenvolvimento',
#   'estrategias',
#   'segmentadas',
#   'otimizacao',
#   'valor',
#   'base',
#   'clientes',
#   'analise',
#   'discussao',
#   'estrategias',
#   'segmentacao',
#   'campanhas',
#   'criacao',
#   'analise',
#   'kpis',
#   'monitorar',
#   'performance',
#   'programa',
#   'contribuir',
#   'desenvolvimento',
#   'acoes',
#   'marketing',
#   'potencializem',
#   'oportunidades',
#   'retencao',
#   'clientes',
#   'expansao',
#   'programa',
#   'assim',
#   'mensurar',
#   'rentabilizacao',
#   'programa',
#   'aplicacao',
#   'inteligencia',
#   'analitica',
#   'negocios',
#   'formular',
#   'analisar',
#   'hipoteses',
#   'ajudem',
#   'tomada',
#   'decisoes',
#   'estrategicas',
#   'dar',
#   'suporte',
#   'acoes',
#   'planejamento',
#   'gestao',
#   'resultados',
#   'finalidade',
#   'garantir',
#   'rentabilidade',
#   'sustentabilidade',
#   'crescimento',
#   'negocios',
#   'auxiliar',
#   'desenvolvimento',
#   'mensuracao',
#   'testes',
#   'b',
#   'modelagem',
#   'analises',
#   'estatisticas',
#   'programa',
#   'pre',
#   'requisitos',
#   'formacao',
#   'superior',
#   'completa',
#   'estatistica',
#   'engenharia',
#   'ciencia',
#   'computacao',
#   'afins',
#   'experiencia',
#   'inteligencia',
#   'analitica',
#   'aplicada',
#   'campanhas',
#   'aquisicao',
#   'clientes',
#   'retencao',
#   'criacao',
#   'estrategias',
#   'ofertas',
#   'personalizadas',
#   'raciocinio',
#   'analitico',
#   'dominio',
#   'pacote',
#   'conhecimento',
#   'avancado',
#   'excel',
#   'disponibilidade',
#   'viagens',
#   'nivel',
#   'minimo',
#   'idioma',
#   'ingles',
#   'intermediariodesejavel',
#   'habilidade',
#   'comunicacao',
#   'conhecimento',
#   'microstrategy',
#   'ferramenta',
#   'intelligence',
#   'bi',
#   'experiencia',
#   'criacao',
#   'indicadores',
#   'performance',
#   'criacao',
#   'modelos',
#   'propensao',
#   'conhecimento',
#   'estatistica',
#   'desejavel',
#   'conhecimento',
#   'marketing',
#   'estrategico',
#   'experiencia',
#   'varejo',
#   'experiencia',
#   'gestao',
#   'base',
#   'clientes'],
#  ['cientista_de_dados',
#   'esperamos',
#   'conhecimentos',
#   'inteligencia',
#   'artificial',
#   'especialmente',
#   'area',
#   'm',
#   'learningcapacidade',
#   'implementacao',
#   'algoritmos',
#   'preditivos',
#   'p',
#   'previsao',
#   'classificacao',
#   'resultados',
#   'conhecimento',
#   '1',
#   'plataformas',
#   'gestao',
#   'dados',
#   'nuvem',
#   'google',
#   'cloud',
#   'aws',
#   'azure',
#   'conhecimento',
#   'lingua',
#   'inglesacapacidade',
#   'organizacao',
#   'limpeza',
#   'dados',
#   'p',
#   'utilizacao',
#   'modelos',
#   'm',
#   'learningconhecimentos',
#   'desejaveis',
#   'conhecimentos',
#   'big',
#   'python',
#   'r',
#   'linguagens',
#   'banco',
#   'dados',
#   'notebook',
#   'jupyter',
#   'bibliotecas',
#   'tensorflow',
#   'keras',
#   'pytorchdiferenciais',
#   'participacao',
#   'competicoes',
#   'm',
#   'learning',
#   'ex',
#   'kaggle',
#   'projetos',
#   'utilizando',
#   'inteligencia',
#   'artificialatividades',
#   'serem',
#   'desenvolvidas',
#   'atuar',
#   'desenvolvimento',
#   'manutencao',
#   'modelos',
#   'machine',
#   'learning',
#   'projetos',
#   'nossos',
#   'clientes',
#   'obtencao',
#   'limpeza',
#   'estruturacao',
#   'dados',
#   'criacao',
#   'treinamento',
#   'validacao',
#   'modelos',
#   'm',
#   'learning',
#   'interagir',
#   'outros',
#   'times',
#   'projetos',
#   'apoio',
#   'diagnostico',
#   'producao',
#   'documentacao',
#   'homologacao',
#   'entregaveis',
#   'visitas',
#   'clientes',
#   'nacionais',
#   'internacionais',
#   'foco',
#   'incansavel',
#   'geracao',
#   'valor',
#   'sustentavel',
#   'nossos',
#   'parceiros',
#   'principalmente',
#   'equipe',
#   'atraves',
#   'treinamentos',
#   'acompanhamento',
#   'constante',
#   'equipe',
#   'experiencias',
#   'praticas',
#   'projetos',
#   'clientes',
#   'outros',
#   'programas',
#   'desenvolvimento',
#   'fazemos',
#   'equipe',
#   'nao',
#   'somente',
#   'melhores',
#   'profissionais',
#   'sim',
#   'melhores',
#   'pessoas'],
#  ...]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
#phrases = Phrases(sent, min_count=30, progress_per=10000)

#class gensim.models.phrases.Phrases(sentences=None, min_count=5, threshold=10.0, 
#max_vocab_size=40000000, delimiter='_', progress_per=10000, scoring='default', common_terms=frozenset([]))

#Detect phrases based on collocation counts.

#Parameters:	
#sentences (iterable of list of str, optional) – The sentences iterable can be simply a list, but for larger corpora, consider a generator that streams the sentences directly from disk/network, See BrownCorpus, Text8Corpus or LineSentence for such examples.
#min_count (float, optional) – Ignore all words and bigrams with total collected count lower than this value.
#threshold (float, optional) – Represent a score threshold for forming the phrases (higher means fewer phrases). A phrase of words a followed by b is accepted if the score of the phrase is greater than threshold. Heavily depends on concrete scoring-function, see the scoring parameter.
#max_vocab_size (int, optional) – Maximum size (number of tokens) of the vocabulary. Used to control pruning of less common words, to keep memory under control. The default of 40M needs about 3.6GB of RAM. Increase/decrease max_vocab_size depending on how much available memory you have.
#delimiter (str, optional) – Glue character used to join collocation tokens, should be a byte string (e.g. b’_’).
#scoring ({'default', 'npmi', function}, optional) –
# Out:
# INFO - 06:49:05: collecting all words and their counts
# INFO - 06:49:05: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 06:49:05: collected 90384 word types from a corpus of 138069 words (unigram + bigrams) and 1675 sentences
# INFO - 06:49:05: using 90384 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %%
bigram = Phraser(phrases)
sentences = bigram[sent]
# Out:
# INFO - 06:49:05: source_vocab length 90384
# INFO - 06:49:06: Phraser built with 91 phrasegrams

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 12459

# %%
word_freq
# Out:
# defaultdict(int,
#             {'cientista_de_dados': 104,
#              'cientista': 14,
#              'dados': 1482,
#              'considerado': 2,
#              'nova': 22,
#              'geracao': 80,
#              'especialistas': 29,
#              'analise': 799,
#              'habilidades': 126,
#              'tecnicas': 247,
#              'resolver': 34,
#              'problemas': 159,
#              'complexos': 31,
#              'curiosidade': 17,
#              'explorar': 19,
#              'quais': 43,
#              'necessitam': 7,
#              'solucao': 113,
#              'conhecimentos': 527,
#              'especificos': 46,
#              'linguagens_programacao': 60,
#              'r_python': 35,
#              'sql': 290,
#              'visualizacao': 49,
#              'spotfire': 12,
#              'powerbi': 31,
#              'cognos': 10,
#              'mining': 17,
#              'exploratoria': 8,
#              'infraestrutura': 73,
#              'big': 145,
#              'hadoop': 87,
#              'mapreduce': 18,
#              'spark': 84,
#              'algoritmos': 71,
#              'regressao': 17,
#              'logistica': 66,
#              'arvore': 11,
#              'decisao': 45,
#              'random': 7,
#              'forest': 4,
#              'xgbooster': 1,
#              'linear': 8,
#              'notebook': 4,
#              'jupyter': 10,
#              'zepellin': 1,
#              'hive': 46,
#              'hbase': 21,
#              'etl': 106,
#              'datastage': 4,
#              'sqoop': 9,
#              'experiencia': 1632,
#              'projetos': 688,
#              'analytics': 212,
#              'machine_learning': 146,
#              'deep_learning': 34,
#              'sentimentos': 2,
#              'conteudo': 28,
#              'nlp': 10,
#              'word2vec': 1,
#              'bag': 1,
#              'words': 1,
#              'git': 27,
#              'gitlab': 2,
#              'hortonworks': 2,
#              'cloudera': 11,
#              'comunicacao': 251,
#              'estatisticas': 49,
#              'foco': 163,
#              'graduacao': 88,
#              'area': 795,
#              'ti': 277,
#              'qualquer': 40,
#              'outra': 17,
#              'acompanhada': 5,
#              'pos_graduacao': 71,
#              'utilizar': 31,
#              'modelos': 196,
#              'matematicos': 24,
#              'estatisticos': 37,
#              'preditivos': 21,
#              'correlacao': 5,
#              'segmentacao': 21,
#              'construir': 62,
#              'solucoes': 387,
#              'apoio': 134,
#              'negocio': 521,
#              'clientes': 914,
#              'analisar': 314,
#              'identificar': 171,
#              'tendencias': 79,
#              'comportamentos': 9,
#              'uso': 102,
#              'ferramentas': 434,
#              'bi': 156,
#              'acompanhar': 323,
#              'desempenho': 158,
#              'producao': 117,
#              'sempre': 71,
#              'cumprindo': 8,
#              'funcao': 121,
#              'alta': 70,
#              'interacao': 45,
#              'diversas': 73,
#              'areas': 475,
#              'empresa': 463,
#              'marketing': 302,
#              'inovacao': 77,
#              'entender': 75,
#              'oportunidades': 247,
#              'propor': 96,
#              'melhorias': 158,
#              'desejavel': 414,
#              'ciencias_computacao': 63,
#              'estatistica': 215,
#              'engenharias': 41,
#              'areas_correlatas': 104,
#              'interpretacao': 19,
#              'refino': 2,
#              'base': 135,
#              'testes': 198,
#              'hipoteses': 13,
#              'estruturar': 31,
#              'dar': 37,
#              'manutencao': 231,
#              'sistemas_informacao': 95,
#              'desenvolver': 355,
#              'capacidade_analitica': 43,
#              'aprimorar': 21,
#              'processos': 804,
#              'meio': 183,
#              'melhoria': 133,
#              'continua': 53,
#              'cursando': 99,
#              'engenharia': 269,
#              'fisica': 41,
#              'matematica': 141,
#              'aplicada': 15,
#              'economia': 108,
#              'diferencial': 142,
#              'gostar': 27,
#              'pensamento': 16,
#              'logico': 35,
#              'apurado': 5,
#              'facilidade': 78,
#              'conhecer': 48,
#              'alguma': 18,
#              'linguagem_programacao': 39,
#              'julia': 6,
#              'nosql': 46,
#              'consulta': 30,
#              'modelar': 11,
#              'gerar': 120,
#              'insights': 94,
#              'selecionar': 10,
#              'melhor': 90,
#              'tecnica': 103,
#              'science': 70,
#              'utilizada': 2,
#              'cada': 86,
#              'gerenciar': 83,
#              'garantindo': 95,
#              'riscos': 107,
#              'arquitetura': 129,
#              'conhecimento': 1256,
#              'ia': 11,
#              'inteligencia_artificial': 35,
#              'jurimetria': 1,
#              'comportamento': 32,
#              'usuario': 48,
#              'realizar': 532,
#              'sprint': 31,
#              'desenvolvimento': 856,
#              'implantacao': 168,
#              'automatizacao': 21,
#              'utilizando': 137,
#              'scripts': 55,
#              'vba': 43,
#              'sap': 122,
#              'script': 23,
#              'outras': 161,
#              'rpa': 10,
#              'projeto': 163,
#              'engloba': 4,
#              'seguintes': 31,
#              'etapas': 30,
#              'pre': 67,
#              'entendimento': 78,
#              'objetivo': 109,
#              'demanda': 65,
#              'levantamento_requisitos': 59,
#              'mapeamento': 103,
#              'stakeholders': 25,
#              'recursos': 86,
#              'necessarios': 98,
#              'participar': 111,
#              'contribuir': 72,
#              'workshop': 1,
#              'eventos': 91,
#              'design': 48,
#              'thinking': 7,
#              'estruturacao': 38,
#              'escopo': 72,
#              'aplicavel': 4,
#              'realizacao': 97,
#              'entrevistas': 24,
#              'pessoas': 152,
#              'chave': 22,
#              'aprofundamento': 1,
#              'restricoes': 11,
#              'proposicao': 13,
#              'alternativas': 15,
#              'processo': 282,
#              'procedimentos': 129,
#              'serem': 41,
#              'automatizados': 19,
#              'desenho': 55,
#              'comparativo': 1,
#              'atual': 5,
#              'proposto': 2,
#              'organizacao': 170,
#              'delimitacao': 1,
#              'prototipacao': 6,
#              'produto': 182,
#              'conjunto': 46,
#              'equipe': 333,
#              'mapeada': 1,
#              'po': 23,
#              'product': 25,
#              'owner': 16,
#              'todas': 118,
#              'bases': 68,
#              'necessarias': 50,
#              'execucao': 127,
#              'levantamento': 89,
#              'direto': 27,
#              'via': 91,
#              'queries': 31,
#              'bancos_dados': 98,
#              'existentes': 43,
#              'articulacao': 5,
#              'tratamento': 48,
#              'limpeza': 28,
#              'levantados': 5,
#              'novos': 189,
#              'outros': 171,
#              'identificados': 12,
#              'durante': 27,
#              'envolvimento': 7,
#              'validacao': 61,
#              'intermediaria': 4,
#              'pos': 64,
#              'preparacao': 58,
#              'apresentacao': 95,
#              'powerpoint': 41,
#              'evidenciando': 1,
#              'principais': 100,
#              'ganhos': 5,
#              'impactos': 39,
#              'trazidos': 1,
#              'visao': 97,
#              'antes': 8,
#              'x': 45,
#              'piloto': 3,
#              'aplicacao': 88,
#              'desenvolvidos': 22,
#              'final': 35,
#              'junto': 189,
#              'mapeados': 3,
#              'ajustes': 18,
#              'solicitadas': 11,
#              'documentacao': 124,
#              'todos': 134,
#              'criterios': 24,
#              'considerados': 11,
#              'premissas': 6,
#              'assumidas': 1,
#              'guia': 6,
#              'operacionalizacao': 10,
#              'definicao': 103,
#              'numero': 8,
#              'sprints': 11,
#              'conclusao': 10,
#              'sera': 73,
#              'estimado': 2,
#              'tabela': 15,
#              'complexidade': 43,
#              'demandas': 153,
#              'terao': 3,
#              'participacao': 93,
#              'contribuicao': 2,
#              'profissionais': 76,
#              'petrobras': 1,
#              'problema': 24,
#              'abordado': 1,
#              'etapa': 24,
#              'deve': 24,
#              'iniciada': 1,
#              'apos': 20,
#              'finalizados': 1,
#              'previstos': 5,
#              'visando': 163,
#              'garantir': 201,
#              'informacoes': 414,
#              'bom': 36,
#              'andamento': 61,
#              'eficacia': 19,
#              'prazo': 58,
#              'semana': 13,
#              '5': 35,
#              'dias': 18,
#              'uteis': 3,
#              'refere': 5,
#              'podem': 11,
#              'variar': 1,
#              'acordo': 179,
#              'item': 8,
#              'estimativa': 8,
#              'esforco': 14,
#              'realzacao': 1,
#              'sao': 115,
#              'apresentadas': 10,
#              'estimativas': 11,
#              'dedicacao': 1,
#              'poderao': 5,
#              'ocorrer': 2,
#              'concomitantes': 1,
#              'tempo': 51,
#              'envolver': 2,
#              'configuracao': 47,
#              'consumo': 31,
#              'escrita': 76,
#              'i': 43,
#              'api': 50,
#              'webservice': 3,
#              'barramento': 4,
#              'servicos': 250,
#              'odata': 2,
#              'oportunidade': 63,
#              'estendida': 2,
#              'deficiencia': 38,
#              'ajudar': 26,
#              'construcao': 123,
#              'analises': 249,
#              'tomada_decisao': 64,
#              'criacao': 231,
#              'indicadores': 243,
#              'controle': 261,
#              'qualidade': 255,
#              'kpi': 22,
#              'migracao': 8,
#              'ambiente': 179,
#              'nuvem': 30,
#              'adicionais': 25,
#              'avulsos': 2,
#              'simulacoes': 18,
#              'complemento': 1,
#              'servico': 34,
#              '4': 26,
#              '1': 43,
#              'necessario': 231,
#              'conforme': 81,
#              'implementacao': 134,
#              'trabalhos': 31,
#              'simulacao': 6,
#              'definido': 6,
#              'banco_dados': 373,
#              'multidimensionais': 8,
#              'selecao': 49,
#              'captura': 18,
#              'estruturados': 54,
#              'nao': 184,
#              'mineracao': 39,
#              'modelagem': 151,
#              'avancadas': 16,
#              'ferramenta': 82,
#              'ex': 46,
#              'power_bi': 88,
#              'linguagens': 58,
#              'python_r': 55,
#              'aprendizagem': 26,
#              'maquina': 32,
#              'knime': 8,
#              'miner': 9,
#              'alem': 78,
#              'profissional': 153,
#              'devera': 14,
#              'integrar': 25,
#              'qualificar': 8,
#              'diferentes': 75,
#              'origens': 7,
#              'grande': 75,
#              'volume': 44,
#              'arquitetando': 3,
#              'estruturas': 32,
#              'ambientes': 74,
#              'computacionais': 9,
#              'ciencia_computacao': 85,
#              'relacionadas': 97,
#              'pacotes': 13,
#              'industrias': 7,
#              'referencia': 8,
#              'driven': 20,
#              'cro': 1,
#              'crm': 90,
#              'tecnologias': 138,
#              'focados': 2,
#              'melhores': 67,
#              'resultados': 308,
#              'contrata': 10,
#              'programador': 6,
#              'porto': 6,
#              'alegre': 2,
#              'rs': 3,
#              'busca': 82,
#              'apaixonadas': 4,
#              'capazes': 5,
#              'extrair': 19,
#              'relevantes': 34,
#              'partir': 58,
#              'gigantescos': 1,
#              'volumes': 21,
#              'voce': 233,
#              'ira': 101,
#              'trabalhar': 164,
#              'maiores': 20,
#              'varejo': 53,
#              'america': 15,
#              'latina': 16,
#              'tendo': 20,
#              'impacto': 35,
#              'vida': 40,
#              'milhoes': 8,
#              'responsabilidades': 116,
#              'estao': 35,
#              'atuar': 351,
#              'colaboracao': 12,
#              'analistas': 25,
#              'modelos_estatisticos': 33,
#              'sustentar': 4,
#              'workflows': 4,
#              'atendam': 23,
#              'necessidades': 232,
#              'empregar': 1,
#              'previsao': 19,
#              'receita': 48,
#              'churne': 1,
#              'grupos': 13,
#              'consumidores': 11,
#              'afinidade': 11,
#              'manipular': 13,
#              'skills': 41,
#              'solido': 17,
#              'programacao': 147,
#              'java': 111,
#              'classificacao': 23,
#              'agrupamento': 3,
#              'predicao': 4,
#              'relacionais': 63,
#              'mysql': 61,
#              'postgresql': 30,
#              'oracle': 131,
#              'ms': 54,
#              'sql_server': 117,
#              'ingles_intermediario': 65,
#              'pytorch': 4,
#              'tensorflow': 20,
#              'diferenciais': 53,
#              'formacao': 163,
#              'ciencias': 23,
#              'exatas': 21,
#              'afins': 100,
#              'nocoes': 54,
#              'grandes': 56,
#              'responsabilidade': 61,
#              'compilacao': 10,
#              'sobre': 268,
#              'fornecendo': 13,
#              'relatorios': 459,
#              'sugestao': 3,
#              'fundamentar': 4,
#              'possibilitar': 6,
#              'tomada': 29,
#              'decisoes': 80,
#              'dentro': 93,
#              'formacao_superior': 105,
#              'computacao': 22,
#              'compativel': 33,
#              'comprovada': 44,
#              'habilidade': 125,
#              'scikit': 10,
#              'learn': 14,
#              'pandas': 16,
#              'aprendizado': 43,
#              'supervisionado': 10,
#              'redes': 75,
#              'neurais': 24,
#              'ingles_avancado': 81,
#              'leitura': 25,
#              'fluente': 56,
#              'computacional': 9,
#              'classica': 1,
#              'curso': 51,
#              'superior_completo': 149,
#              'tecnologia_informacao': 104,
#              'areas_afins': 109,
#              'avancados': 32,
#              'contabil': 41,
#              'sistema': 349,
#              'financeiro': 106,
#              'preferencia': 20,
#              'plataformas': 79,
#              'azure': 68,
#              'aws': 65,
#              'profundo': 19,
#              'modernas': 5,
#              'funcionam': 4,
#              'apenas': 5,
#              'los': 26,
#              'academica': 45,
#              'pessoal': 32,
#              'ciencia': 34,
#              'tableau': 60,
#              'conceitos': 50,
#              'keras': 12,
#              'correlatas': 29,
#              'organizar': 35,
#              'validar': 44,
#              'gerados': 14,
#              'quantidades': 22,
#              'transforma': 4,
#              'gestores': 44,
#              'interessados': 9,
#              'possam': 24,
#              'tomar': 6,
#              'eficientes': 10,
#              'aplicar': 22,
#              'variacoes': 7,
#              'dentre': 25,
#              'resolucao_problemas': 37,
#              'buscar': 56,
#              'padroes': 78,
#              'procurar': 3,
#              'ordem': 8,
#              'elaborar': 265,
#              'dashboards': 86,
#              'regras_negocio': 45,
#              'seguranca': 138,
#              'informacao': 92,
#              'performance': 184,
#              'disponiveis': 30,
#              'prover': 31,
#              'claras': 2,
#              'consistentes': 5,
#              'transformar': 36,
#              'brutos': 3,
#              'discutir': 10,
#              'backoffice': 7,
#              'negocios': 415,
#              'estrategicos': 34,
#              'evolucao': 48,
#              'avaliar': 90,
#              'prescritivos': 3,
#              'manuseio': 9,
#              'solidos': 29,
#              'manipulacao': 61,
#              'fundamentos': 13,
#              'plataforma': 135,
#              'preferencialmente': 61,
#              'alteryx': 12,
#              'metodologias_ageis': 42,
#              'kanban': 20,
#              'scrum': 89,
#              'logica': 34,
#              'fuzzy': 4,
#              'cursos': 101,
#              'adquirir': 3,
#              'processar': 8,
#              'varias': 15,
#              'fontes': 63,
#              'sistemas': 659,
#              'end': 27,
#              'determinar': 7,
#              'abordagem': 14,
#              'estrategica': 22,
#              'gerenciamento': 174,
#              'transformacao': 48,
#              'etls': 13,
#              'pipelines': 18,
#              'streamings': 1,
#              'realtime': 1,
#              'suportar': 88,
#              'correcao': 19,
#              'bugs': 9,
#              'longo': 34,
#              'pipeline': 30,
#              'colaborar': 15,
#              'cientistas': 21,
#              'mapear': 45,
#              'campos': 7,
#              'preparar': 54,
#              'analiticos': 20,
#              'usando': 46,
#              'python': 104,
#              'versao': 20,
#              'dependencias': 4,
#              'maven': 4,
#              'pip': 2,
#              'fluxos': 34,
#              'trabalho': 268,
#              'branches': 2,
#              'pull': 2,
#              'requests': 4,
#              'dominio': 127,
#              'r': 111,
#              'vivencia': 150,
#              'distribuidos': 16,
#              'incluindo': 89,
#              'clusters': 4,
#              'sharding': 2,
#              'quorum': 2,
#              'ecossistema': 25,
#              'jupiter': 3,
#              'notebooks': 7,
#              'acessiveis': 3,
#              'facilitando': 8,
#              'solucionar': 21,
#              'orientacao': 48,
#              'variedade': 9,
#              'ordens': 11,
#              'bem': 132,
#              'detectar': 3,
#              'usar': 21,
#              'text': 8,
#              'criar': 138,
#              'novas': 216,
#              'escalaveis': 9,
#              'graduacao_completa': 51,
#              'streaming': 4,
#              'motores': 4,
#              'minning': 1,
#              'clusterizacao': 11,
#              'menos': 20,
#              'dois': 11,
#              'criticidade': 4,
#              'metricas': 51,
#              'acompanhamento': 301,
#              'ramo': 33,
#              'automotivo': 6,
#              'componentes': 19,
#              'eletronicos': 5,
#              'certificacoes': 19,
#              'itil': 28,
#              'metodologias': 61,
#              'siebel': 1,
#              'fazer_parte': 36,
#              'super': 6,
#              'precisamos': 15,
#              'salve': 2,
#              'ml': 16,
#              'pesquisas': 36,
#              'redes_sociais': 38,
#              'geolocalizacao': 3,
#              'microdados': 2,
#              'scraping': 2,
#              'implementar': 94,
#              'compreender': 16,
#              'matlab': 8,
#              'mongodb': 32,
#              'couchdb': 3,
#              'cuidando': 2,
#              'objetivos': 74,
#              'especifico': 8,
#              'solucionado': 4,
#              'mecanismos': 9,
#              'assegure': 3,
#              'assertividade': 10,
#              'resultado': 68,
#              'capacidade': 138,
#              'comunicar': 28,
#              'eficiencia': 38,
#              'mindlaber': 2,
#              'apaixonado': 11,
#              'educacao': 45,
#              'muita': 7,
#              'vontade': 24,
#              'positivo': 2,
#              'criancas': 3,
#              'sociedade': 3,
#              'aprender': 52,
#              'desafios': 69,
#              'inovar': 4,
#              'jovem': 5,
#              'mega': 4,
#              'mao': 9,
#              'massa': 15,
#              'resiliente': 2,
#              'suficiente': 3,
#              'encarar': 7,
#              'diversos': 60,
#              'rotina': 43,
#              'dinamica': 22,
#              'rapido': 19,
#              'crescimento': 70,
#              'trazer': 19,
#              'enxergar': 3,
#              'razao': 2,
#              'acordar': 1,
#              'manha': 4,
#              'vestir': 1,
#              'camisa': 1,
#              'milhares': 2,
#              'linhas': 22,
#              'codigo': 40,
#              'potente': 1,
#              'social': 44,
#              'educacional': 14,
#              'experiencias': 49,
#              'mind': 1,
#              'lab': 1,
#              'diaria': 9,
#              'horizontal': 1,
#              'aberto': 10,
#              'dinamico': 31,
#              'alto': 57,
#              'venha': 33,
#              'parte': 39,
#              'investigadores': 1,
#              'ensino_superior': 364,
#              'completo': 313,
#              'projetar': 28,
#              'fornece': 8,
#              'acesso': 45,
#              'seguro': 8,
#              'conjuntos': 22,
#              'interface': 81,
#              'area_comercial': 89,
#              'companhia': 91,
#              'reunindo': 1,
#              'requisitos': 473,
#              'entregando': 14,
#              'completas': 3,
#              'modele': 1,
#              'metadados': 4,
#              'ad': 17,
#              'hoc': 12,
#              'construidos': 2,
#              'manter': 173,
#              'paineis': 33,
#              'continuos': 3,
#              'impulsionar': 13,
#              'reconhecer': 4,
#              'adotar': 4,
#              'melhores_praticas': 35,
#              'integridade': 30,
#              'teste': 44,
#              'ajustar': 9,
#              'aplicativos': 38,
#              'consultas': 60,
#              'perfil': 128,
#              'raiz': 10,
#              'recuando': 1,
#              'contexto': 9,
#              'amplo': 14,
#              'ampla': 11,
#              'gama': 5,
#              'fonte': 14,
#              'sabendo': 1,
#              'atualizado': 37,
#              'avancos': 2,
#              'execute': 5,
#              'pilotos': 4,
#              'escalar': 3,
#              'aumento': 20,
#              'melhorar': 33,
#              'continuamente': 4,
#              'extracao': 65,
#              'relatorio': 26,
#              'automatizando': 2,
#              'simplificando': 2,
#              'suporte': 295,
#              'autoatendimento': 1,
#              'bacharel': 19,
#              'campo': 47,
#              'tecnico': 115,
#              'relacionado': 14,
#              'coleta': 41,
#              'formulacao': 5,
#              'excelente': 29,
#              'ssis': 19,
#              'escala': 19,
#              'forte': 38,
#              'verbal': 44,
#              'eficazmente': 1,
#              'equipes': 106,
#              'historico': 7,
#              'paixao': 25,
#              'prospera': 1,
#              'inovador': 11,
#              'ritmo': 4,
#              'acelerado': 7,
#              'map': 3,
#              'reduce': 3,
#              'bibliotecas': 15,
#              'possua': 3,
#              'exploracao': 19,
#              'idealmente': 4,
#              'tambem': 76,
#              'probabilidade': 8,
#              'saiba': 8,
#              'metodos': 48,
#              'series': 12,
#              'temporais': 12,
#              'lineares': 2,
#              'cluster': 6,
#              'exploratorias': 4,
#              'preditivas': 4,
#              'multivariadas': 3,
#              'inferencia': 4,
#              'bayesiana': 1,
#              'linguagem': 89,
#              'natural': 6,
#              'completa': 76,
#              'nebulosa': 3,
#              'similaridade': 4,
#              'tensowflow': 3,
#              'svm': 8,
#              'logistic': 3,
#              'regression': 4,
#              'kmeans': 3,
#              'dendogramacao': 3,
#              'orquestracao': 9,
#              'nodered': 3,
#              'nodejs': 8,
#              'diferencias': 3,
#              'otimizacao': 85,
#              'cloudant': 3,
#              'sas': 57,
#              'spss': 8,
#              'campanhas': 86,
#              'estrategias': 115,
#              'orientadores': 2,
#              'iniciativas': 38,
#              'fazer': 143,
#              'follow_up': 52,
#              'vendas': 871,
#              'desempenhar': 9,
#              'checagem': 2,
#              'dar_suporte': 63,
#              'tendencia': 6,
#              'probabilidades': 2,
#              'previsoes': 6,
#              'reunir': 6,
#              'publicacao': 11,
#              'apoiar': 172,
#              'consultores': 25,
#              'hands': 21,
#              'operacional': 48,
#              'pratica': 42,
#              'modelagem_dados': 90,
#              'rfv': 2,
#              'lifetime': 2,
#              'value': 10,
#              'propensao': 4,
#              'compra': 51,
#              'analitico': 54,
#              'converter': 3,
#              'planos': 99,
#              'acoes': 188,
#              'sucesso': 33,
#              'excel_avancado': 84,
#              'relevancia': 3,
#              'tamanho': 5,
#              'considerando': 24,
#              'enriquecimento': 4,
#              'viabilizacao': 5,
#              'amostragens': 1,
#              'otimizacoes': 7,
#              'baseadas': 7,
#              'investigar': 5,
#              'interpretar': 19,
#              'questoes': 15,
#              'aplicadas': 6,
#              'apresentar': 47,
#              'outputs': 1,
#              'warehouses': 6,
#              'produzir': 12,
#              'detalhadas': 5,
#              'variaveis': 15,
#              'rotinas': 131,
#              'automatizar': 13,
#              'processamento': 72,
#              'planejamento': 205,
#              'estrategia': 126,
#              'lake': 23,
#              'forma': 127,
#              'estruturada': 6,
#              'visuais': 7,
#              'gerir': 29,
#              'kpis': 60,
#              'governanca': 47,
#              'estruturando': 3,
#              'mantendo': 25,
#              'dicionario': 8,
#              'models': 5,
#              'conceituais': 1,
#              'praticos': 5,
#              'cassandra': 18,
#              'riak': 1,
#              'redis': 10,
#              'tais': 53,
#              'google': 91,
#              'cloud': 129,
#              'klipfolio': 4,
#              'qlink': 3,
#              'utilizacao': 76,
#              'distribuidas': 5,
#              'variadas': 4,
#              'atuais': 24,
#              'tensor': 1,
#              'flow': 9,
#              'h2o': 2,
#              'desejavel_conhecimento': 116,
#              'mensagens': 5,
#              'rendimento': 2,
#              'kafka': 28,
#              'digital': 100,
#              'aplicacoes': 97,
#              'amazon': 10,
#              'mllib': 1,
#              'assim': 39,
#              'regressoes': 3,
#              'recomendacao': 8,
#              'reinforcement': 1,
#              'learning': 6,
#              'softwares': 43,
#              'exemplo': 27,
#              'minitab': 3,
#              'familiaridade': 27,
#              'mdm': 3,
#              'jira': 12,
#              'jenkins': 10,
#              'devsecops': 2,
#              'agile': 32,
#              'lgpd': 5,
#              'gdpr': 4,
#              'regulamentacoes': 3,
#              'excel': 278,
#              'access': 29,
#              'altamente': 10,
#              'microsoft': 81,
#              '70': 7,
#              '767': 1,
#              '768': 1,
#              '775': 1,
#              '778': 1,
#              '779': 1,
#              'mcsa': 3,
#              'ibm': 44,
#              'certified': 4,
#              'archtecht': 1,
#              'cap': 3,
#              'csa': 1,
#              'sido': 3,
#              'responsavel': 247,
#              'estudos': 102,
#              'apresentado': 2,
#              'solida': 32,
#              '3': 31,
#              'anos': 57,
#              'certificado': 13,
#              'professional': 6,
#              'lidar': 37,
#              'coletar': 21,
#              'serao': 64,
#              'utilizados': 15,
#              'interagir': 47,
#              'engenheiros': 14,
#              'priorizar': 15,
#              'entregas': 57,
#              'implantar': 39,
#              'selecionados': 2,
#              'adotando': 4,
#              'reportar': 14,
#              'justificar': 1,
#              'adotadas': 5,
#              'visitas': 70,
#              'interacoes': 15,
#              'fim': 78,
#              'real': 32,
#              'necessidade': 41,
#              'im': 1,
#              'compreensao': 19,
#              'distribuicoes': 4,
#              'gestao': 633,
#              'gigante': 3,
#              'nacional': 19,
#              'atuante': 2,
#              'segmento': 67,
#              'saude': 103,
#              ...})

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['experiencia',
#  'dados',
#  'conhecimento',
#  'clientes',
#  'vendas',
#  'desenvolvimento',
#  'processos',
#  'analise',
#  'area',
#  'projetos']

# %%
import multiprocessing
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

from gensim.models import Word2Vec

w2v_model = Word2Vec(min_count=5,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.05, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

#Os hiperparâmetros utilizados são:
#
#min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)
#window = int - The maximum distance between the current and predicted word within a sentence. E.g. window words on the left and window words on the left of our target - (2, 10)
#size = int - Dimensionality of the feature vectors. - (50, 300)
#sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial. - (0, 1e-5)
#alpha = float - The initial learning rate - (0.01, 0.05)
#min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
#negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no - negative sampling is used. - (5, 20)
#workers = int - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 06:49:06: collecting all words and their counts
# INFO - 06:49:06: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 06:49:07: collected 12459 word types from a corpus of 131678 raw words and 1675 sentences
# INFO - 06:49:07: Loading a fresh vocabulary
# INFO - 06:49:07: effective_min_count=5 retains 3683 unique words (29% of original 12459, drops 8776)
# INFO - 06:49:07: effective_min_count=5 leaves 117568 word corpus (89% of original 131678, drops 14110)
# INFO - 06:49:07: deleting the raw counts dictionary of 12459 items
# INFO - 06:49:07: sample=6e-05 downsamples 1307 most-common words
# INFO - 06:49:07: downsampling leaves estimated 56686 word corpus (48.2% of prior 117568)
# INFO - 06:49:07: estimated required memory for 3683 words and 300 dimensions: 10680700 bytes
# INFO - 06:49:07: resetting layer weights
# Time to build vocab: 0.01 mins

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=70, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 06:49:07: training model with 3 workers on 3683 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# INFO - 06:49:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:49:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:49:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:49:07: EPOCH - 1 : training on 131678 raw words (56723 effective words) took 0.4s, 150626 effective words/s
# INFO - 06:49:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:49:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:49:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:49:07: EPOCH - 2 : training on 131678 raw words (56520 effective words) took 0.4s, 145488 effective words/s
# INFO - 06:49:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:49:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 06:49:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 06:49:08: EPOCH - 3 : training on 131678 raw words (56462 effective words) took 0.4s, 134646 effective words/s
# INFO - 06:49:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 06:49
# Time to train the model: 0.48 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# INFO - 06:49:35: precomputing L2-norms of word weight vectors

# %%
w2v_model.wv.most_similar(positive=["cientista_de_dados"])
# Out:
# [('cientista', 0.5577467679977417),
#  ('veja', 0.5333106517791748),
#  ('quantitativo', 0.508604109287262),
#  ('procura', 0.5060161352157593),
#  ('candidatura', 0.48915573954582214),
#  ('alguem', 0.47243842482566833),
#  ('ibope', 0.46521610021591187),
#  ('identificou', 0.45993903279304504),
#  ('voce', 0.4566195011138916),
#  ('qualificacoes', 0.44782018661499023)]

# %%
w2v_model.wv.most_similar(positive=["data_science"])
# Out:
# [('arquitetar', 0.5341538786888123),
#  ('data_analytics__', 0.4732263386249542),
#  ('analista_de_dados', 0.470899373292923),
#  ('combinacao', 0.45450282096862793),
#  ('engenheiro_de_machine_learning', 0.4490140974521637),
#  ('sera_responsavel', 0.44591110944747925),
#  ('inteligencia_de_negocios', 0.4395129680633545),
#  ('cientista_de_dados', 0.4259726405143738),
#  ('procura', 0.40454062819480896),
#  ('ira', 0.40233713388442993)]

# %%
w2v_model.wv.most_similar(positive=["analista_de_dados"])
# Out:
# [('analista_de_negocios', 0.6052438020706177),
#  ('data_analytics', 0.48533278703689575),
#  ('inteligencia_de_negocios', 0.48162224888801575),
#  ('desenvolvedor', 0.4739876687526703),
#  ('data_science', 0.470899373292923),
#  ('atribuicoes', 0.46307018399238586),
#  ('cargo', 0.4513874351978302),
#  ('algar', 0.4398368000984192),
#  ('ira', 0.4322722554206848),
#  ('resumo', 0.42220166325569153)]

# %%
w2v_model.wv.most_similar(positive=["engenheiro_de_dados"])
# Out:
# [('_', 0.6440074443817139),
#  ('__atuar', 0.6228703260421753),
#  ('combinacao', 0.46754294633865356),
#  ('instrumentacao', 0.46533510088920593),
#  ('disciplina', 0.42861247062683105),
#  ('ingestao', 0.42164841294288635),
#  ('wrangling', 0.40944308042526245),
#  ('pipelines', 0.4088803827762604),
#  ('engenheiro_de_machine_learning', 0.4042019248008728),
#  ('requisito', 0.39483290910720825)]

# %%
w2v_model.wv.most_similar(positive=["engenheiro_de_machine_learning"])
# Out:
# [('engenheiro', 0.6591110229492188),
#  ('engineer', 0.5949043035507202),
#  ('about', 0.5538548231124878),
#  ('business_inteligence', 0.5519773364067078),
#  ('berrini', 0.5040953755378723),
#  ('arquiteto', 0.49987319111824036),
#  ('1999', 0.49501678347587585),
#  ('essence', 0.4776212275028229),
#  ('desenvolvedor', 0.4705734848976135),
#  ('data_science', 0.4490140974521637)]

# %%
w2v_model.wv.most_similar(positive=["business_inteligence"])
# Out:
# [('apenas', 0.5615507364273071),
#  ('engenheiro_de_machine_learning', 0.551977276802063),
#  ('brasilia', 0.5098543167114258),
#  ('essence', 0.5069822072982788),
#  ('vemseralelo', 0.48911696672439575),
#  ('fazem', 0.48796939849853516),
#  ('extensiva', 0.48054951429367065),
#  ('multinacional', 0.47593778371810913),
#  ('talento', 0.4696602523326874),
#  ('search', 0.4529438018798828)]

# %%
w2v_model.wv.most_similar(positive=["business_analytics"])
# Out:
# [('analyst', 0.5942438840866089),
#  ('role', 0.5401005744934082),
#  ('coordenacao', 0.5210456848144531),
#  ('level', 0.5061421394348145),
#  ('qliksense', 0.4980844259262085),
#  ('responsible', 0.4973374009132385),
#  ('making', 0.4885672926902771),
#  ('into', 0.4803102910518646),
#  ('based', 0.4695841073989868),
#  ('improve', 0.4657936096191406)]

# %%
w2v_model.wv.most_similar(positive=["analista_de_negocios"])
# Out:
# [('analista_de_dados', 0.6052438020706177),
#  ('inteligencia_de_negocios', 0.5629537105560303),
#  ('cargo', 0.49149370193481445),
#  ('desempenhadas', 0.48529431223869324),
#  ('algar', 0.47016650438308716),
#  ('data_analytics', 0.46542736887931824),
#  ('descricao', 0.4389726221561432),
#  ('inscreva', 0.4325169622898102),
#  ('berrini', 0.42603546380996704),
#  ('atribuicoes', 0.4151609241962433)]

# %%
w2v_model.wv.most_similar(positive=["data_analytics"])
# Out:
# [('berrini', 0.5894970297813416),
#  ('analista_de_dados', 0.48533278703689575),
#  ('analista_de_negocios', 0.46542736887931824),
#  ('descricao', 0.4561271667480469),
#  ('especialista', 0.435146689414978),
#  ('arquiteto', 0.414844274520874),
#  ('arquitetar', 0.4126988649368286),
#  ('principais_responsabilidades', 0.4081076979637146),
#  ('liderar', 0.40715301036834717),
#  ('desempenhadas', 0.4052121937274933)]

# %%
w2v_model.wv.most_similar(positive=["paulo_pedro"])
# Out:
# [('fone', 0.9876514077186584),
#  ('55', 0.9773253798484802),
#  ('97109', 0.8809674978256226),
#  ('11', 0.8034920692443848),
#  ('2031', 0.7513972520828247),
#  ('hobbies', 0.6939111948013306),
#  ('transporteassistencia', 0.6920338869094849),
#  ('pablostanger', 0.6803475618362427),
#  ('more', 0.6686612963676453),
#  ('refeicaoauxilio', 0.6609153747558594)]

# %%
w2v_model.wv.similarity("cientista_de_dados", "paulo_pedro")
# Out:
# 0.11024665

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
#    for wrd_score in close_words:
#        wrd_vector = model.wv.__getitem__([wrd_score[0]])
#        word_labels.append(wrd_score[0])
#        color_list.append('blue')
#        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=8).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    global df1
    df1 = df.copy()
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
#tsnescatterplot(w2v_model, "cientista_de_dados", ["data_science", "business_analytics","business_inteligence","engenheiro_de_machine_learning",'analista_de_dados', 'data_analytics', 'engenheiro_de_dados', 'analista_de_negocios'])

# %%
tsnescatterplot(w2v_model, "paulo_pedro", ["cientista_de_dados","data_science", "business_analytics","business_inteligence","engenheiro_de_machine_learning",'analista_de_dados', 'data_analytics', 'engenheiro_de_dados', 'analista_de_negocios'])

# %%
#tsnescatterplot(w2v_model, "cientista_de_dados", [t[0] for t in w2v_model.wv.most_similar(positive=["cientista_de_dados"], topn=20)][10:])

# %%
df1
# Out:
#             x           y                           words  color
# 0  -90.454369 -273.492401                     paulo_pedro    red
# 1  192.035904  -94.868546              cientista_de_dados  green
# 2  -16.406012  -98.688789                    data_science  green
# 3  -81.297577  221.472687              business_analytics  green
# 4  114.345909 -262.759949            business_inteligence  green
# 5   49.608936   57.382553  engenheiro_de_machine_learning  green
# 6 -225.330093 -119.029068               analista_de_dados  green
# 7  123.483543  232.261154                  data_analytics  green
# 8  258.406281   77.810600             engenheiro_de_dados  green
# 9 -158.757416   53.523651            analista_de_negocios  green

# %%
for termo in termo_pesquisado:
    df1.loc[(df1.words == termo),'similarity'] = w2v_model.wv.similarity(termo, "paulo_pedro")
    
df1
# Out:
#             x           y                           words  color  similarity
# 0  -90.454369 -273.492401                     paulo_pedro    red         NaN
# 1  192.035904  -94.868546              cientista_de_dados  green    0.110247
# 2  -16.406012  -98.688789                    data_science  green    0.090332
# 3  -81.297577  221.472687              business_analytics  green    0.027436
# 4  114.345909 -262.759949            business_inteligence  green    0.284916
# 5   49.608936   57.382553  engenheiro_de_machine_learning  green    0.209508
# 6 -225.330093 -119.029068               analista_de_dados  green    0.005692
# 7  123.483543  232.261154                  data_analytics  green   -0.050245
# 8  258.406281   77.810600             engenheiro_de_dados  green    0.106145
# 9 -158.757416   53.523651            analista_de_negocios  green   -0.041109

# %%
df1.to_csv('resultadoSimilaridades.csv')
